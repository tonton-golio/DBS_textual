# %% [markdown]
# # Shareholder deck; data miner

# %%
from DBS_utils import *

# %% [markdown]
# ## Make list of companies

# %%
PWD = "/Users/antongolles/Documents/Work/ITU-Research/DBS_textual/"
relative_location = "../data/Shareholder_decks/"
list_dir = os.listdir(PWD+relative_location)

companies = get_company_names(list_dir)
text_dicts = get_text_dicts(list_dir)
#print('companies: ',companies, '\n text dicts: ',[i[33:] for i in text_dicts])
#print("Number of companies = ", len(companies))

# %% [markdown]
# ## extract text and save as dictionary

# %%
print("Number of companies = ", len(companies))
#make_text_dictionary(companies, PWD, relative_location,build_on_date='2022-05-18')
# Out:
# Number of companies =  91

# %% [markdown]
# ## Load dictionary

# %%
date_today = str(date.today())
date_latest = '2022-05-18'

file = np.load(relative_location+f'text_from_shareholder_decks_{date_latest}.npz', allow_pickle=True)
#file = np.load(relative_location+'../'+f'text_from_shareholder_decks_{date_latest}.npz', allow_pickle=True)
text_dict = file[file.files[0]].item()
text_dict['google']['google_2020_Q2']['text'][:100]
# Out:
# 'Alphabet Announces Second Quarter 2020 Results\n\nMOUNTAIN  VIEW,  Calif.  –  July  30,  2020  – Alpha'

# %% [markdown]
# ## Cleaning

# %%
# Lets see if we have an appropriate number of each
fullness_dict = {}
for company in text_dict.keys():
    fullness_dict[company] = []
    for report in text_dict[company].keys():
        year, quarter = int(report.split('_')[1]), int(report.split('_')[2][1])
        fullness_dict[company].append(year+quarter*.25-.25)

        
plt.figure(figsize=(18,4))
for index,company in enumerate(fullness_dict.keys()):
    plt.scatter([index]*len(fullness_dict[company]), fullness_dict[company])
    
plt.xticks(range(len(fullness_dict.keys())), fullness_dict.keys(), rotation=90);

# %%
# Lets have a look at whether the lengths are approximately the same for different reports of a single company
lengths = [[len(text_dict[company][report]['text']) for report in text_dict[company].keys()] for company in text_dict.keys()]

plt.figure(figsize=(18,4))
plt.boxplot(lengths)
plt.xticks(range(len(fullness_dict.keys())), fullness_dict.keys(), rotation=90);
plt.yscale('log')
# Out:
# findfont: Font family ['cmsy10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmr10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmtt10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmmi10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmb10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmss10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmex10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['DejaVu Sans Display'] not found. Falling back to DejaVu Sans.

# %%
# Lets find the outliers
lengths_company = {}
for company in text_dict.keys():
    lengths_company[company] = {}
    for report in text_dict['monster'].keys():
        try:
            report = company+'_'+'_'.join(report.split('_')[1:])
            report_length = len(text_dict[company][report]['text']) 
        except:
            report_length = None
        lengths_company[company][''.join(report.split('_')[1:])] = report_length 
lengths_df = pd.DataFrame.from_dict((lengths_company)).sort_index()
lengths_df
# Out:
#         apple   paccar  starbucks  moderna  honeywell  twitter   Dexcom  \
# 2017Q1   8161      NaN      31793      NaN      18805    47496      NaN
# 2017Q2   3636      NaN      40306      NaN      22338    36445      NaN
# 2017Q3   8068      NaN      44455      NaN      20695    52250      NaN
# 2017Q4   9695      NaN      59081      NaN      26205    52495      NaN
# 2018Q1   9853      NaN      36781      NaN      24565    41616      NaN
# 2018Q2  10664      NaN      51029      NaN      28669    53870      NaN
# 2018Q3   9656      NaN      49421      NaN      29023    52887      NaN
# 2018Q4  11070      NaN      59788  22904.0      36915    61233      NaN
# 2019Q1  10924      NaN      32664  24211.0      26242    43583  13024.0
# 2019Q2  10974      NaN      46244  35049.0       9739    58065  14099.0
# 2019Q3  10366      NaN      49647  42221.0      10509    52677  15093.0
# 2019Q4  10188      NaN      54923  31193.0      11440    54545  13558.0
# 2020Q1  10283      NaN      33655  27542.0      10833    53022  12782.0
# 2020Q2  10783      NaN      49187  31113.0      14153    57724   9772.0
# 2020Q3  10726      NaN      49187  27089.0      13032    61309  10027.0
# 2020Q4  10475  24529.0      54911  30760.0      14446    64759   9566.0
# 2021Q1  10346  17438.0      41293  35869.0      10833    49805  13722.0
# 2021Q2  10634  19265.0      44646  38904.0      14153    62218  13726.0
# 2021Q3   9804  22777.0      47640  42030.0      13032    61610  11098.0
# 2021Q4  10476  22858.0      52192  38671.0      12656    75185   2778.0
# 2022Q1  10275  16559.0      40504  31488.0      15797    36337   2691.0
#
#         lululemon  Marriott  skyworksinc  ...       jd  illumina  cadence  \
# 2017Q1        NaN   78013.0         6463  ...  45005.0   30638.0      NaN
# 2017Q2        NaN  102215.0        31254  ...  51328.0   32742.0  16961.0
# 2017Q3        NaN  102149.0        31413  ...  59501.0   30439.0  16688.0
# 2017Q4        NaN    7935.0        33629  ...  61987.0   31982.0  24129.0
# 2018Q1     5243.0   54085.0        26485  ...  48919.0   23884.0  18243.0
# 2018Q2     5173.0   87381.0        28280  ...  54758.0   26441.0  18577.0
# 2018Q3     6022.0   88408.0        28730  ...  49450.0   27061.0  18511.0
# 2018Q4     4748.0   91723.0        31263  ...  60230.0   28944.0  23583.0
# 2019Q1     3720.0   68440.0        26023  ...  44952.0   22064.0  18139.0
# 2019Q2     3754.0   86010.0        29753  ...  45739.0   25630.0  18245.0
# 2019Q3     4475.0   81536.0        30789  ...  48525.0   25543.0  18921.0
# 2019Q4     5681.0   88532.0        32358  ...  59064.0   26612.0  24124.0
# 2020Q1     4666.0   63870.0        25538  ...  42365.0   20045.0  19471.0
# 2020Q2     5847.0   77376.0        30590  ...      NaN   24048.0  18792.0
# 2020Q3     5743.0   77036.0        29305  ...  43990.0   24657.0  18967.0
# 2020Q4     5648.0   87660.0        29983  ...  52788.0   29071.0  23174.0
# 2021Q1     5385.0   66494.0        25093  ...  42123.0   12189.0  18382.0
# 2021Q2     5580.0   82724.0        26329  ...  44600.0   27573.0  18153.0
# 2021Q3     5536.0   82669.0        27671  ...  42831.0   37096.0  18054.0
# 2021Q4     6165.0   81683.0        28098  ...  53318.0   40178.0  38373.0
# 2022Q1        NaN       NaN        25456  ...      NaN       NaN  31756.0
#
#         MatchGroup  verisign       KLA  monster  fortinet  netEase  tmobile
# 2017Q1         NaN     27302   17118.0    16406       NaN  38851.0  34762.0
# 2017Q2         NaN     21397   17201.0    20547   16774.0  38063.0  38388.0
# 2017Q3         NaN     20514   16517.0    20026   10618.0  40630.0  39501.0
# 2017Q4         NaN     22775  519796.0    22483   12653.0  54381.0  47645.0
# 2018Q1     14849.0     27706   14525.0    19132   18276.0  44565.0  40521.0
# 2018Q2     14086.0     28319   18162.0    23810   17810.0  44095.0  43570.0
# 2018Q3     14510.0     30060   17909.0    24012   20689.0  48296.0  43213.0
# 2018Q4     17238.0     30256   17406.0    25507   23738.0  58369.0  50115.0
# 2019Q1     13519.0     25512   14804.0    19081   19847.0  44625.0  39915.0
# 2019Q2     13174.0     24720   16845.0    21548   18717.0      NaN  41872.0
# 2019Q3     14872.0     24538   20780.0    22999   18178.0  47590.0  43963.0
# 2019Q4     19216.0     27436       NaN    23685   25773.0      NaN  48736.0
# 2020Q1     26922.0     20159   21552.0    22841   16473.0      NaN  47220.0
# 2020Q2     14292.0     18829   26353.0    27437   21199.0  51334.0  37672.0
# 2020Q3     12907.0     19160   31902.0    26702   24037.0  48922.0  36061.0
# 2020Q4     15948.0     20287   20900.0    30432   38185.0  56701.0  38445.0
# 2021Q1     52016.0     18999   14747.0    20796   21528.0  40903.0  36044.0
# 2021Q2     57481.0     18998   14403.0    23896   21713.0  43624.0  36979.0
# 2021Q3     65453.0     19009   15525.0    25019   22631.0  45981.0  37886.0
# 2021Q4     61360.0     19750   15628.0    30892   32856.0  54021.0  42538.0
# 2022Q1     53623.0     18008   15907.0    22526       NaN   3029.0      NaN
#
# [21 rows x 90 columns]

# %%
np.array([col+' '*(15-len(col)) for col in lengths_df.columns])
# Out:
# array(['apple          ', 'paccar         ', 'starbucks      ',
#        'moderna        ', 'honeywell      ', 'twitter        ',
#        'Dexcom         ', 'lululemon      ', 'Marriott       ',
#        'skyworksinc    ', 'NXP            ', 'crowdstrike    ',
#        'costco         ', 'pepsico        ', 'docusign       ',
#        'airbnb         ', 'zscaler        ', 'amazon         ',
#        'baidu          ', 'paychex        ', 'marvell        ',
#        'workday        ', 'booking        ', 'biogen         ',
#        'google         ', 'microsoft      ', 'amgen          ',
#        'fastenal       ', 'intuit         ', 'activision     ',
#        'micron         ', 'ansys          ', 'broadcom       ',
#        'siriusXM       ', 'walgreens      ', 'texasIntruments',
#        'tesla          ', 'meta           ', 'LamResearch    ',
#        'verisk         ', 'cisco          ', 'AEP            ',
#        'analogDevices  ', 'cognizant      ', 'autodesk       ',
#        'ebay           ', 'fiserv         ', 'gilead         ',
#        'seagen         ', 'ADP            ', 'oreillyauto    ',
#        'amd            ', 'netflix        ', 'idexx          ',
#        'adobe          ', 'exelon         ', 'align          ',
#        'paloAlto       ', 'nvidia         ', 'atlassian      ',
#        'microchip      ', 'splunk         ', 'CSX            ',
#        'lucid          ', 'paypal         ', 'xcelenergy     ',
#        'charter        ', 'mondelez       ', 'okta           ',
#        'datadog        ', 'zoom           ', 'mercadoLibre   ',
#        'comcast        ', 'cintas         ', 'EA             ',
#        'appliedMaterials', 'pinduoduo      ', 'astrazeneca    ',
#        'vertex         ', 'kraftHeinz     ', 'jd             ',
#        'illumina       ', 'cadence        ', 'MatchGroup     ',
#        'verisign       ', 'KLA            ', 'monster        ',
#        'fortinet       ', 'netEase        ', 'tmobile        '],
#       dtype='<U16')

# %%
lengths_df['Marriott']
# Out:
# 2017Q1     78013.0
# 2017Q2    102215.0
# 2017Q3    102149.0
# 2017Q4      7935.0
# 2018Q1     54085.0
# 2018Q2     87381.0
# 2018Q3     88408.0
# 2018Q4     91723.0
# 2019Q1     68440.0
# 2019Q2     86010.0
# 2019Q3     81536.0
# 2019Q4     88532.0
# 2020Q1     63870.0
# 2020Q2     77376.0
# 2020Q3     77036.0
# 2020Q4     87660.0
# 2021Q1     66494.0
# 2021Q2     82724.0
# 2021Q3     82669.0
# 2021Q4     81683.0
# 2022Q1         NaN
# Name: Marriott, dtype: float64

# %% [markdown]
# ## Look for key words

# %%
import re

def count_re_matches(re_string, string):
    return len(re.findall(re_string, string))

def count_re_matches_diff(re_string, string):
    return len(set(re.findall(re_string, string)))

# %%
import re
p = re.compile("b")
for m in p.finditer('ba1bb2c3d4'):
    print(m)
    print(m.start(), m.group())
# Out:
# <re.Match object; span=(0, 1), match='b'>
# 0 b
# <re.Match object; span=(3, 4), match='b'>
# 3 b
# <re.Match object; span=(4, 5), match='b'>
# 4 b

# %%
file = np.load('../data/keywords_dict_v4.npz', allow_pickle=1)
keyword_dict = file[file.files[0]].item()
keyword_dict['Digital']
# Out:
# {0: {'text': 'Digital', 'lemmas': ['Digital'], 'stems': ['digit']},
#  1: {'text': 'Digitization', 'lemmas': ['digitization'], 'stems': ['digit']},
#  2: {'text': 'digitalization',
#   'lemmas': ['digitalization'],
#   'stems': ['digit']},
#  3: {'text': 'Ecosystem', 'lemmas': ['ecosystem'], 'stems': ['ecosystem']},
#  4: {'text': 'Platform', 'lemmas': ['platform'], 'stems': ['platform']},
#  5: {'text': 'Data', 'lemmas': ['datum'], 'stems': ['data']},
#  6: {'text': 'Information', 'lemmas': ['information'], 'stems': ['inform']},
#  7: {'text': 'information-based',
#   'lemmas': ['information', '-', 'base'],
#   'stems': ['inform', '-', 'base']},
#  8: {'text': 'knowledge', 'lemmas': ['knowledge'], 'stems': ['knowledg']},
#  9: {'text': 'Artificial Intelligence',
#   'lemmas': ['Artificial', 'Intelligence'],
#   'stems': ['artifici', 'intellig']},
#  10: {'text': 'AI', 'lemmas': ['AI'], 'stems': ['ai']},
#  11: {'text': 'IT', 'lemmas': ['it'], 'stems': ['it']},
#  12: {'text': 'IT-enabled',
#   'lemmas': ['it', '-', 'enable'],
#   'stems': ['it', '-', 'enabl']},
#  13: {'text': 'Information technologies',
#   'lemmas': ['information', 'technology'],
#   'stems': ['inform', 'technolog']},
#  14: {'text': 'Information technology',
#   'lemmas': ['information', 'technology'],
#   'stems': ['inform', 'technolog']}}

# %%
companies = text_dict.keys()
for company in tqdm(companies):
    reports = text_dict[company].keys()
    for report in reports:
        string = text_dict[company][report]['text']
        for cat in keyword_dict.keys():
            count = 0
            for index in keyword_dict[cat].keys():
                (text, lemmas, stems) =     (keyword_dict[cat][index]['text'], 
                                            keyword_dict[cat][index]['lemmas'], 
                                            keyword_dict[cat][index]['stems'])
                found = False
                while found == False:
                    for i in [text, lemmas, stems]:
                        if type(i) == list:
                            i = ' '.join(i)
                        finding = count_re_matches(i, string)
                        if finding != 0:
                            count += finding
                            found=True
                            break
                    break
                        
            #print(company,report,cat,count)
            text_dict[company][report][cat] = count
# Out:
# 100%|████████| 90/90 [02:01<00:00,  1.35s/it]

# %% [markdown]
# #### convert to DataFrame and format

# %%
df = pd.concat({k: pd.DataFrame(v).T for k, v in text_dict.items()}, axis=0).drop(columns=['text'])
df.reset_index(inplace=True)

df=df[:-1] # cuz the last one is currently bad

df['level_2'] = df['level_1'].apply(get_yearMonth)
df.rename({'level_2': 'period', 'level_0':'company'}, axis=1, inplace=True)

df = df.groupby(by=['period', 'company']).sum()
df.to_csv('../data/results_dataframe_{}.csv'.format(date_today))
df.head()
# Out:
#                                     level_1  Digital  \
# period     company
# 2017-03-01 ADP                  ADP_2017_Q1       62
#            AEP                  AEP_2017_Q1      178
#            EA                    EA_2017_Q1       36
#            KLA                  KLA_2017_Q1       92
#            LamResearch  LamResearch_2017_Q1       72
#
#                         Recombination/Integration  \
# period     company
# 2017-03-01 ADP                                 49
#            AEP                                 84
#            EA                                  57
#            KLA                                 64
#            LamResearch                         59
#
#                         Scope of Digital Business Strategy  \
# period     company
# 2017-03-01 ADP                                          30
#            AEP                                          21
#            EA                                           25
#            KLA                                          29
#            LamResearch                                   8
#
#                         Scale of Digital Business Strategy  \
# period     company
# 2017-03-01 ADP                                          67
#            AEP                                          85
#            EA                                           74
#            KLA                                          76
#            LamResearch                                  55
#
#                         Speed of Digital Business Strategy  \
# period     company
# 2017-03-01 ADP                                          41
#            AEP                                          70
#            EA                                           63
#            KLA                                          53
#            LamResearch                                  23
#
#                         Sources of Value Creation and Capture
# period     company
# 2017-03-01 ADP                                             48
#            AEP                                             52
#            EA                                             120
#            KLA                                             56
#            LamResearch                                     54

# %% [markdown]
# ## Vizualization

# %%
pwd
# Out:
# '/Users/antongolles/Documents/Work/ITU-Research/DBS_textual'

# %%
df = pd.read_csv('../data/results_dataframe_{}.csv'.format('2022-08-12'))#, index_col=[0,1])
df['period']=pd.to_datetime(df.period)
df.sort_values(['company', 'period'], inplace=True)

# %%
df[df['company'] == 'cisco'].head(3)
# Out:
#         period company        level_1  Digital  Recombination/Integration  \
# 19  2017-03-01   cisco  cisco_2017_Q1       28                        112
# 369 2018-09-01   cisco  cisco_2018_Q3       19                        113
# 437 2018-12-01   cisco  cisco_2018_Q4       20                        137
#
#      Scope of Digital Business Strategy  Scale of Digital Business Strategy  \
# 19                                   84                                 145
# 369                                  73                                 156
# 437                                  80                                 167
#
#      Speed of Digital Business Strategy  Sources of Value Creation and Capture
# 19                                  128                                    115
# 369                                 119                                    117
# 437                                 137                                    146

# %%
fig, ax = plt.subplots(5,1, figsize=(16,12), sharex=True)

sns.barplot(data=df,x='period',y='Digital', hue='company', ax=ax[0],)

sns.barplot(data=df,x='period',y='Scope of Digital Business Strategy', hue='company', ax=ax[1])
sns.barplot(data=df,x='period',y='Scale of Digital Business Strategy', hue='company', ax=ax[2])
sns.barplot(data=df,x='period',y='Speed of Digital Business Strategy', hue='company', ax=ax[3])
sns.barplot(data=df,x='period',y='Sources of Value Creation and Capture', hue='company', ax=ax[4])

[ax[i].legend([]) for i in range(0,5)]

plt.tight_layout()

# %%
fig, ax = plt.subplots(1,5, figsize=(15,5))

topics = df.columns[3:]
for i, t in enumerate(topics):
    ax[i].scatter(df.period, df[t], label=t)
    ax[i].legend()
    ax[i].set_yscale('log')
    #ax[i].set_xticks([],[])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/mz/gfjk9jc50c7598gd12qlyv240000gn/T/ipykernel_48865/2204323664.py in <module>
#       3 topics = df.columns[3:]
#       4 for i, t in enumerate(topics):
# ----> 5     ax[i].scatter(df.period, df[t], label=t)
#       6     ax[i].legend()
#       7     ax[i].set_yscale('log')
#
# IndexError: index 5 is out of bounds for axis 0 with size 5
# findfont: Font family ['cmsy10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmr10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmtt10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmmi10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmb10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmss10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmex10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['DejaVu Sans Display'] not found. Falling back to DejaVu Sans.

# %%
cols = 8
fig, ax = plt.subplots(len(companies)//cols+1,cols, figsize=(25,15), sharex=True)
for index, company in enumerate(companies):
    ax_index = index//ax.shape[1], index%ax.shape[1] 
    for i, t in enumerate(topics):

        df2 =df[df['company'] == company]
        ax[ax_index].plot(df2.period, df2[t], label=t)
        ax[ax_index].set_title(company)

ax[0,0].legend()
plt.tight_layout()
plt.savefig('new_all.png', dpi=600)

# %%
cols = 5
fig, ax = plt.subplots(len(companies)//cols+1,cols, figsize=(25,25),sharey=True)
for index, company in enumerate(companies):
    ax_index = index//ax.shape[1], index%ax.shape[1] 
    for i, t in enumerate(topics):

        df2 =df[df['company'] == company]
        ax[ax_index].plot(df2.period, df2[t], label=t)
        ax[ax_index].set_title(company)

#ax[0,0].legend()
plt.tight_layout()

# %% [markdown]
# ### bubble plot-> a bunch of pies

# %%
cat
# Out:
# 'Sources of Value Creation and Capture'

# %% [markdown]
# ## How good is the keyword dictionary?
# * word count, like mathches for each term
# *

# %%
### Total Hits

# %%
matches_on_words = {}


matches_on_words_company = {}
for company in companies:
    matches_on_words_company[company] = {}

    
matches_on_words_quarter = {}
for quarter in df.level_1.apply(lambda x: ''.join(x.split('_')[1:])).unique():
    matches_on_words_quarter[quarter] = {}


companies = text_dict.keys()
for company in tqdm(companies):
    
    reports = text_dict[company].keys()
    for report in reports:
        string = text_dict[company][report]['text']
        for cat in keyword_dict.keys():
            count = 0
            for index in keyword_dict[cat].keys():
                (text, lemmas, stems) =     (keyword_dict[cat][index]['text'], 
                                            keyword_dict[cat][index]['lemmas'], 
                                            keyword_dict[cat][index]['stems'])
                found = False
                while found == False:
                    for i in [text, lemmas, stems]:
                        if type(i) == list:
                            i = ' '.join(i)
                        finding = count_re_matches_diff(i, string)
                        if (finding != 0 and found == False):
                            if text in matches_on_words.keys():
                                matches_on_words[text]['count'] += 1
                            else:
                                matches_on_words[text] = {'count' : 1, 'category':cat}
                                
                            if text in matches_on_words_company[company].keys():
                                matches_on_words_company[company][text] += 1
                            else:
                                matches_on_words_company[company][text] = 1
                                
                            quarter = ''.join(report.split('_')[1:])
                            if text in matches_on_words_quarter[quarter].keys():
                                matches_on_words_quarter[quarter][text] += 1
                            else:
                                matches_on_words_quarter[quarter][text] = 1
                            
                            count += finding
                            found=True
                            break
                    break
# Out:
# 100%|████████| 90/90 [02:15<00:00,  1.51s/it]

# %%
matches_on_words_df = pd.DataFrame.from_dict(matches_on_words).T.sort_values('count', ascending=False).reset_index()
matches_on_words_df
# Out:
#                                   index count  \
# 0                               sharing  2920
# 1                          availability  2698
# 2                            continuous  2634
# 3                           competitive  2376
# 4                               control  1942
# ..                                  ...   ...
# 407                  multi-disciplinary     1
# 408  application programming interfaces     1
# 409                         first-mover     1
# 410                        market reach     1
# 411                              acumen     1
#
#                                category
# 0             Recombination/Integration
# 1    Scale of Digital Business Strategy
# 2             Recombination/Integration
# 3    Scope of Digital Business Strategy
# 4    Scope of Digital Business Strategy
# ..                                  ...
# 407  Scope of Digital Business Strategy
# 408  Scale of Digital Business Strategy
# 409  Speed of Digital Business Strategy
# 410  Scope of Digital Business Strategy
# 411           Recombination/Integration
#
# [412 rows x 3 columns]

# %%
matches_on_words_df.to_csv('../data/matches_on_words_df{}.csv'.format(date_today))

# %%
fig, ax = plt.subplots(1,6, figsize=(13,6))

for index, cat in enumerate(matches_on_words_df.category.unique()):
    
    sns.barplot(data=matches_on_words_df[matches_on_words_df.category == cat],
                x='index', y='count', ax=ax[index]);
    ax[index].set_xticklabels(ax[index].get_xticklabels(),rotation = 90);
    ax[index].set_title(cat.split()[0])
    
plt.tight_layout()

# %%
fig, ax = plt.subplots(6,1, figsize=(13,20))

for index, cat in enumerate(matches_on_words_df.category.unique()):
    
    sns.barplot(data=matches_on_words_df[matches_on_words_df.category == cat],
                x='index', y='count', ax=ax[index]);
    ax[index].set_xticklabels(ax[index].get_xticklabels(),rotation = 90);
    ax[index].set_title(cat)
    ax[index].set_ylabel(cat)
plt.tight_layout()
plt.savefig('figures/Dictionary_hits_01.png', dpi=400)

# %%
fig, ax = plt.subplots(figsize=(18,5))
sns.barplot(data=matches_on_words_df, x='index', y='count',  hue='category', ax=ax);
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90);

# %%
pd.DataFrame.from_dict(matches_on_words_company).to_csv('../data/matches_on_words_company_df{}.csv'.format(date_today))

# %%
count = 0
companies = text_dict.keys()
for company in tqdm(companies):
    
    reports = text_dict[company].keys()
    for report in reports:
        count +=1
        
count
# Out:
# 100%|█████| 90/90 [00:00<00:00, 14619.96it/s]
# 1511

# %%
T = [[keyword_dict[cat][i]['text'] for i in keyword_dict[cat].keys()] for cat in keyword_dict.keys()]
#t_flat = t[0]+t[1]+t[2]+t[3]+t[4]

# %%
for cat, T1 in zip(keyword_dict.keys(), T):
    print('\n### '+ cat+' ###')
    for t in T1:
        if t not in matches_on_words_df['index'].unique():
            print(t)
# Out:
# ### Digital ###
# IT-enabled
#
# ### Recombination/Integration ###
# recoupling
# continuum
# problem setting
# connotation
# solidarity
# post-industrial
# deluge
#
# ### Scope of Digital Business Strategy ###
# functional silo
# process silo
# transfunctional
# multifunctional
# cross-disciplinary
# IT-enabled business processes
# digitized product architecture
# digital product architecture
# informationbased
#
# ### Scale of Digital Business Strategy ###
# multisided
# scale down
# quality of service
# chatter
# crossselling
# digital setting
# plug-and-play
#
# ### Speed of Digital Business Strategy ###
# just-in-time
# fast-paced
# interfirm
# non-value
# conceptual
#
# ### Sources of Value Creation and Capture ###
# value capture
# remixing
# resyndication
# disintermediation
# conceptualize
# cocreate

# %% [markdown]
# ## ML
# - kMeans
# - look for similarity of variables

# %%
X = df.values[:,3:]

np.shape(X)

# %%
# Account for term frequency

# TFIDF

# %% [markdown]
# ## Performance

# %%
dd = {}
for i in [[keyword_dict[cat][index]['text'] for index in keyword_dict[cat].keys()] for cat in keyword_dict]:
    for j in i:
        if j in dd:
            dd[j] += 1
        else:
            dd[j] =1

# %%
pd.DataFrame.from_dict(dd, orient='index').sort_values(0, ascending=False)
# Out:
#               0
# learning      3
# competitive   2
# experience    2
# flexibility   2
# social media  2
# ...          ..
# connectivity  1
# big data      1
# data          1
# protocols     1
# difference    1
#
# [443 rows x 1 columns]

# %%
pd.DataFrame.from_dict(keyword_dict)
# Out:
#                                                    DBS  \
# 0    {'text': 'Digital technology', 'lemmas': ['Dig...
# 1    {'text': 'Digital era', 'lemmas': ['Digital', ...
# 2    {'text': 'Digital resources', 'lemmas': ['Digi...
# 3    {'text': 'Platform', 'lemmas': ['platform'], '...
# 4    {'text': 'Recombination/Integration', 'lemmas'...
# ..                                                 ...
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
#
#                     Scope of Digital Business Strategy  \
# 0    {'text': 'Scope', 'lemmas': ['scope'], 'stems'...
# 1    {'text': 'fusion', 'lemmas': ['fusion'], 'stem...
# 2    {'text': 'integration', 'lemmas': ['integratio...
# 3    {'text': 'IT strategy', 'lemmas': ['it', 'stra...
# 4    {'text': 'barrier', 'lemmas': ['barrier'], 'st...
# ..                                                 ...
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
#
#                     Scale of Digital Business Strategy  \
# 0    {'text': 'Scale', 'lemmas': ['scale'], 'stems'...
# 1    {'text': 'rapidly', 'lemmas': ['rapidly'], 'st...
# 2    {'text': 'effectively', 'lemmas': ['effectivel...
# 3    {'text': 'IT infrastructure', 'lemmas': ['it',...
# 4    {'text': 'infrastructure', 'lemmas': ['infrast...
# ..                                                 ...
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
#
#                     Speed of Digital Business Strategy  \
# 0    {'text': 'speed', 'lemmas': ['speed'], 'stems'...
# 1    {'text': 'accelerate', 'lemmas': ['accelerate'...
# 2    {'text': 'accelerating', 'lemmas': ['accelerat...
# 3    {'text': 'product launch', 'lemmas': ['product...
# 4    {'text': 'just-in-time', 'lemmas': ['just', '-...
# ..                                                 ...
# 111  {'text': 'tomorrow', 'lemmas': ['tomorrow'], '...
# 112  {'text': 'realignment', 'lemmas': ['realignmen...
# 113  {'text': 'adaptation', 'lemmas': ['adaptation'...
# 114  {'text': 'apps', 'lemmas': ['app'], 'stems': [...
# 115  {'text': 'insights', 'lemmas': ['insight'], 's...
#
#                  Sources of Value Creation and Capture
# 0    {'text': 'source', 'lemmas': ['source'], 'stem...
# 1    {'text': 'value', 'lemmas': ['value'], 'stems'...
# 2    {'text': 'capture', 'lemmas': ['capture'], 'st...
# 3    {'text': 'leveraging', 'lemmas': ['leverage'],...
# 4    {'text': 'leverage', 'lemmas': ['leverage'], '...
# ..                                                 ...
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
#
# [116 rows x 5 columns]
