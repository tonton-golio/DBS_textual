# %% [markdown]
# # Keywords dictionary

# %% [markdown]
# ### Imports and function definitions

# %%
import numpy as np  # for saving dictionary at the end 

import spacy  # for lemmanizing
nlp = spacy.load('en_core_web_sm')  # here we could easily use a bigger model

from nltk.stem import PorterStemmer  # for stemming
ps = PorterStemmer()  # this can also be changed out for other prebuilts

def remove_trailing_spaces(string):
    '''simple while loop for removing trailing spaces. returns string less trailing spaces.'''
    while string[-1] == ' ':
        string = string[:-1]
        
    return string

# %% [markdown]
# ### Load text and place in dictionary

# %%
filename = '../data/dictionary_v2.txt'  
# load keywords from text file. Assumes entries are line seperated and categories are seperate by 3 lines
with open(filename) as f:
    text=f.read()[:-1]
    
text
# Out:
# 'DBS\nDigital technology\nDigital era\nDigital resources\nPlatform\nRecombination/Integration\nRecombination\nCombination\nCombining\ncombine\ncoupling\ndecoupling\nrecoupling\ncontinuum\ndomino\ntranscend\nloyalty\nharmony\nsolution\nproblem setting\nconnotation\nsolidarity\novercoming limits\nknowledge\nskills\nskilled\nexperience\ncomplexity\nhyper\nreact\ncontinuous\nchange\nagility\nagile\ngeneric\nquality\nflexibility\nleadership\nlearning\nacumen\nniche\nmultiplicity\nchoice\nsavvy\ninformed\nproliferation\nadvancement\nexpertise\nexpert\ncreativity\nspirit\nshare\npost-industrial\ndifferent\ndeluge\norganic\nknowledge factory\nflexibility\nvariety\nevolve\nidea\ncognitive\nvirtual\npersonalization\nintelligence\ncommunity\npractice\nintegration\ncluster\nsegments\nworkgroup\nteam\ninterface\nportfolio\nknowledge-based\ncompetence\ncompetencies\ncompetent\nversatile\nsharing\nexperience\nco-locate\nco-location\nseamless\nproject\nconvene\ndisperse\ncycle\naccumulate\nlearning\ndistribution\ncloseness\ncollaboration\ncustomization\nreform\nreshape\ndiverse\ndiverted\n\n\nScope of Digital Business Strategy\nScope \nfusion\nintegration\nIT strategy\nbarrier\nbusiness strategy\nencompassing\ntranscend \nfunctional silo\nprocess silo\nsilo\ncore\nexploit \ndigitization of products\ndigital product\ndigital service\ndigitization of service\ninformation \nproduct information\nservice information\necosystem\nbusiness ecosystem\ndigital ecosystem\ndynamic ecosystem\ncorporate scope\nportfolio \ncontrol\nownership\ndiversification \nextend product reach\nextend market reach \nboundaries \nrelationship \nenvironment \ncompetitive \ncross-functional \ntransfunctional\nmultifunctional\nmulti-disciplinary \ncross-disciplinary\nIT-enabled business processes \ninformation exchanges\ndigital platforms \ninside\noutside \ninterconnected \nbroader\nembedded\ndigital design of product\ndigital design of service\ninteroperability\nkey digital resource\nlinkage\nnovel digital resource\nexpand the scope \ndigitized product architecture\ndigital product architecture\nbits and bytes \ndigital infrastructure \nprotocols \ndata\ninformation \nsocial media\nbig data \nconnectivity \ninformationbased \nmetrics \nhardware\nsoftware\nconnected \ndigital connections \ndigital conditions\nsupply Chain\nsupply network \ndigitally intensive\nalliances\npartnerships\ncompetitors\nspaces\nniches\npartners \norchestration\nmultifaceted\ndata rich\ndynamic\ndigital dependency\ncoverage\ngeographic\n\n\nScale of Digital Business Strategy\nScale \nrapidly\neffectively \nIT infrastructure\ninfrastructure\nEnable\nbolster \ndynamic capability\nnetwork effects\nmultisided platforms\ndata abundance\ninformation abundance\nknowledge abundance\nvolume \ncloud\ndriver\nprofitability\ncost \nunit cost\nphysical\nscale up\nscale down\navailability \nreliance \non-demand \nshared \nconfigurable\ncomputing\nself-service\nvirtualized \nelastic \nutilization\naccess \nmeasure\nquality of service \noperations\nfunctional\nability \nadapt \nrequirement\nmarketplace\npay-as-you-go \npressure\npotential\ninterconnected partnerships\ninterconnections\nweb page\nbroadband\nsmart \ndevice \namplified \nnetworked abundance \ninternet of things\nIoT\nquantities\nheterogeneous \ncontinuous\nbasis \nchatter \nsocial networks\ncrowdsourcing\nedge\nmachine-to-machine\nsensor\noptions \ncrossselling\ncross-selling\ntogether\ndigital setting\nsetting\nmodularize \nmodul \nplug-and-play \ndigital assets \napplication programming interfaces\nAPI\nweb services\n\n\nSpeed of Digital Business Strategy\nspeed\naccelerate\naccelerating \nproduct launch\njust-in-time\nlaunch\nlearning \nimprove\nimproving \ndecision-making\ndecision\nbolster \nquickly\nquick\nformation\nprovide \ncomplementary \nsense\nrespond\ncycle\nreal-time\ntime\ntimely\ncentral \npervasive \nseries\nimprovement \nhybrid \nproduct introduction\nintroduction\ninitiative \nadd\ndimension\nclock \nrecalibrate\ncalibrate \npred ...

# %%
filename = '../data/dictionary_v4.txt'  
# load keywords from text file. Assumes entries are line seperated and categories are seperate by 3 lines
with open(filename) as f:
    text=f.read()[:-1]
    
text
# Out:
# 'Digital\nDigital\nDigitization\ndigitalization\nEcosystem\nPlatform\nData\nInformation\ninformation-based \nknowledge\nArtificial Intelligence\nAI\nIT\nIT-enabled\nInformation technologies\nInformation technology\n\n\nRecombination/Integration\nRecombination\nCombination\nCombining\ncombine\ncoupling\ndecoupling\nrecoupling\ncontinuum\ndomino\ntranscend\nloyalty\nharmony\nsolution\nproblem setting\nconnotation\nsolidarity\novercoming\nlimits\novercoming \nknowledge\nskills\nskilled\nexperience\ncomplexity\nhyper\nreact\ncontinuous\nchange\nagility\nagile\ngeneric\nquality\nflexibility\nleadership\nlearning\nacumen\nniche\nmultiplicity\nchoice\nsavvy\ninformed\nproliferation\nadvancement\nexpertise\nexpert\ncreativity\nspirit\nshare\npost-industrial\ndifferent\ndeluge\norganic\nfactory\nflexibility\nvariety\nevolve\nidea\ncognitive\nvirtual\npersonalization\nintelligence\ncommunity\npractice\nintegration\ncluster\nsegments\nworkgroup\nteam\ninterface\nportfolio\nknowledge-based\ncompetence\ncompetencies\ncompetent\nversatile\nsharing\nexperience\nco-locate\nco-location\nseamless\nproject\nconvene\ndisperse\ncycle\naccumulate\nlearning\ndistribution\ncloseness\ncollaboration\ncustomization\nreform\nreshape\ndiverse\ndiverted\n\n\nScope of Digital Business Strategy\nScope \nfusion\nintegration\nIT strategy\nbarrier\nbusiness strategy\nencompassing\ntranscend \nfunctional silo\nprocess silo\nsilo\ncore\nexploit \nproducts\nproduct\nservice\ncorporate\nportfolio \ncontrol\nownership\ndiversification \nextend\nproduct reach\nmarket reach \nboundaries \nrelationship \nenvironment \ncompetitive \ncross-functional \ntransfunctional\nmultifunctional\nmulti-disciplinary \ncross-disciplinary\nIT-enabled business processes \nexchanges\ninside\noutside \ninterconnected \nbroader\nembedded\ndesign\ninteroperability\nresource\nlinkage\nnovel \nexpand  \ndigitized product architecture\ndigital product architecture\nbits\nbytes \nprotocols \ndata\ninformation \nsocial media\nbig data \nconnectivity \ninformationbased \nmetrics \nhardware\nsoftware\nconnected \nconnections \nconditions\nsupply Chain\nsupply network \nintensive\nalliances\npartnerships\ncompetitors\nspaces\nniches\npartners \norchestration\nmultifaceted\nrich\ndependency\ncoverage\ngeographic\nsyndicate\nalliance\n\n\nScale of Digital Business Strategy\nScale \nrapidly\neffectively \ninfrastructure\ninfrastructure\nEnable\nbolster \ndynamic\nnetwork effects\nmultisided\nabundance\nvolume \ncloud\ndriver\nprofitability\ncost \nunit cost\nphysical\nscale up\nscale down\navailability \nreliance \non-demand \nshared \nconfigurable\ncomputing\nself-service\nvirtualized \nelastic \nutilization\naccess \nmeasure\nquality of service \noperations\nfunctional\nability \nadapt \nrequirement\nmarketplace\npay-as-you-go \npressure\npotential\ninterconnected\npartnerships\ninterconnections\nweb\npage\nbroadband\nsmart \ndevice \namplified \nnetwork\nabundance \ninternet of things\nIoT\nquantities\nheterogeneous \ncontinuous\nbasis \nchatter \nsocial networks\ncrowdsourcing\nedge\nmachine-to-machine\nsensor\noptions \ncrossselling\ncross-selling\ntogether\ndigital setting\nsetting\nmodularize \nmodul \nplug-and-play \ndigital assets \napplication programming interfaces\nAPI\nweb services\n\n\nSpeed of Digital Business Strategy\nSpeed\nDynamic\ndynamism\naccelerate\naccelerating \nproduct launch\njust-in-time\nlaunch\nlearning \nimprove\nimproving \ndecision-making\ndecision\nbolster \nquickly\nquick\nformation\nprovide \ncomplementary \nsense\nrespond\ncycle\nreal-time\ntime\ntimely\ncentral \npervasive \nseries\nimprovement \nhybrid \nproduct introduction\nintroduction\ninitiative \nadd\ndimension\nclock \nrecalibrate\ncalibrate \npredictable\nimprovement\nfunctionality \nmultiyear\nsequence\nremain\ndecade\nrecent\ncombine\nbandwidth\nmobile\nplan\nplanned\nobsolescence\nrecognize\nrespond\nfast-paced \npace \ninnovation\nimplementation\nfundamental \ncompetitive\nsuccess\nsurvival \ncoordin ...

# %%
lst = [i.split('\n') for i in text.split('\n\n\n')]

dic = {}
for i in lst:
    dic[i[0]] = {}
    for index, word in enumerate(i[1:]):
        dic[i[0]][index]= {'text': remove_trailing_spaces(word)}

# %% [markdown]
# ### Stemming and Lemmanizing

# %%
for key in dic.keys():
    for key2 in dic[key].keys():
        doc = nlp(dic[key][key2]['text'])
        lemmas = [word.lemma_ for word in doc]
        dic[key][key2]['lemmas'] = lemmas
        stems = [ps.stem(str(word)) for word in doc]
        dic[key][key2]['stems'] = stems
[(key, len(list(dic[key]))) for key in dic.keys()]
# Out:
# [('Digital', 15),
#  ('Recombination/Integration', 94),
#  ('Scope of Digital Business Strategy', 80),
#  ('Scale of Digital Business Strategy', 78),
#  ('Speed of Digital Business Strategy', 120),
#  ('Sources of Value Creation and Capture', 94)]

# %% [markdown]
# ### Save dict

# %%
np.savez('../data/keywords_dict_v4.npz', dic)

# %%
file = np.load('../data/keywords_dict_v4.npz', allow_pickle=1)
dic_loaded = file[file.files[0]].item()

# %%
dic_loaded
# Out:
# {'Digital': {0: {'text': 'Digital', 'lemmas': ['Digital'], 'stems': ['digit']},
#   1: {'text': 'Digitization', 'lemmas': ['digitization'], 'stems': ['digit']},
#   2: {'text': 'digitalization',
#    'lemmas': ['digitalization'],
#    'stems': ['digit']},
#   3: {'text': 'Ecosystem', 'lemmas': ['ecosystem'], 'stems': ['ecosystem']},
#   4: {'text': 'Platform', 'lemmas': ['platform'], 'stems': ['platform']},
#   5: {'text': 'Data', 'lemmas': ['datum'], 'stems': ['data']},
#   6: {'text': 'Information', 'lemmas': ['information'], 'stems': ['inform']},
#   7: {'text': 'information-based',
#    'lemmas': ['information', '-', 'base'],
#    'stems': ['inform', '-', 'base']},
#   8: {'text': 'knowledge', 'lemmas': ['knowledge'], 'stems': ['knowledg']},
#   9: {'text': 'Artificial Intelligence',
#    'lemmas': ['Artificial', 'Intelligence'],
#    'stems': ['artifici', 'intellig']},
#   10: {'text': 'AI', 'lemmas': ['AI'], 'stems': ['ai']},
#   11: {'text': 'IT', 'lemmas': ['it'], 'stems': ['it']},
#   12: {'text': 'IT-enabled',
#    'lemmas': ['it', '-', 'enable'],
#    'stems': ['it', '-', 'enabl']},
#   13: {'text': 'Information technologies',
#    'lemmas': ['information', 'technology'],
#    'stems': ['inform', 'technolog']},
#   14: {'text': 'Information technology',
#    'lemmas': ['information', 'technology'],
#    'stems': ['inform', 'technolog']}},
#  'Recombination/Integration': {0: {'text': 'Recombination',
#    'lemmas': ['recombination'],
#    'stems': ['recombin']},
#   1: {'text': 'Combination', 'lemmas': ['combination'], 'stems': ['combin']},
#   2: {'text': 'Combining', 'lemmas': ['combine'], 'stems': ['combin']},
#   3: {'text': 'combine', 'lemmas': ['combine'], 'stems': ['combin']},
#   4: {'text': 'coupling', 'lemmas': ['couple'], 'stems': ['coupl']},
#   5: {'text': 'decoupling', 'lemmas': ['decouple'], 'stems': ['decoupl']},
#   6: {'text': 'recoupling', 'lemmas': ['recouple'], 'stems': ['recoupl']},
#   7: {'text': 'continuum', 'lemmas': ['continuum'], 'stems': ['continuum']},
#   8: {'text': 'domino', 'lemmas': ['domino'], 'stems': ['domino']},
#   9: {'text': 'transcend', 'lemmas': ['transcend'], 'stems': ['transcend']},
#   10: {'text': 'loyalty', 'lemmas': ['loyalty'], 'stems': ['loyalti']},
#   11: {'text': 'harmony', 'lemmas': ['harmony'], 'stems': ['harmoni']},
#   12: {'text': 'solution', 'lemmas': ['solution'], 'stems': ['solut']},
#   13: {'text': 'problem setting',
#    'lemmas': ['problem', 'set'],
#    'stems': ['problem', 'set']},
#   14: {'text': 'connotation', 'lemmas': ['connotation'], 'stems': ['connot']},
#   15: {'text': 'solidarity', 'lemmas': ['solidarity'], 'stems': ['solidar']},
#   16: {'text': 'overcoming', 'lemmas': ['overcome'], 'stems': ['overcom']},
#   17: {'text': 'limits', 'lemmas': ['limit'], 'stems': ['limit']},
#   18: {'text': 'overcoming', 'lemmas': ['overcome'], 'stems': ['overcom']},
#   19: {'text': 'knowledge', 'lemmas': ['knowledge'], 'stems': ['knowledg']},
#   20: {'text': 'skills', 'lemmas': ['skill'], 'stems': ['skill']},
#   21: {'text': 'skilled', 'lemmas': ['skilled'], 'stems': ['skill']},
#   22: {'text': 'experience', 'lemmas': ['experience'], 'stems': ['experi']},
#   23: {'text': 'complexity', 'lemmas': ['complexity'], 'stems': ['complex']},
#   24: {'text': 'hyper', 'lemmas': ['hyper'], 'stems': ['hyper']},
#   25: {'text': 'react', 'lemmas': ['react'], 'stems': ['react']},
#   26: {'text': 'continuous', 'lemmas': ['continuous'], 'stems': ['continu']},
#   27: {'text': 'change', 'lemmas': ['change'], 'stems': ['chang']},
#   28: {'text': 'agility', 'lemmas': ['agility'], 'stems': ['agil']},
#   29: {'text': 'agile', 'lemmas': ['agile'], 'stems': ['agil']},
#   30: {'text': 'generic', 'lemmas': ['generic'], 'stems': ['gener']},
#   31: {'text': 'quality', 'lemmas': ['quality'], 'stems': ['qualiti']},
#   32: {'text': 'flexibility', 'lemmas': ['flexibility'], 'stems': ['flexibl']},
#   33: {'text': 'leadership',
#    'lemmas': ['leadership'],
#    'stems': ['leadership']},
#   34: {'text': 'learning', 'lemmas': ['learn'], 'stems': ['learn']},
#   35: {'text': 'acumen', 'lemmas': ['acuman'], 'stems': ['acumen']},
#   36: {'text': 'niche', 'lemmas': ['niche'], 'stems': ['nich']},
#   37: {'text': 'multiplicity',
#    'lemmas': ['multiplicity'],
#    'stems': ['multipl']},
#   38: {'text': 'choice', 'lemmas': ['choice'], 'stems': ['choic']},
#   39: {'text': 'savvy', 'lemmas': ['savvy'], 'stems': ['savvi']},
#   40: {'text': 'informed', 'lemmas': ['inform'], 'stems': ['inform']},
#   41: {'text': 'proliferation',
#    'lemmas': ['proliferation'],
#    'stems': ['prolifer']},
#   42: {'text': 'advancement', 'lemmas': ['advancement'], 'stems': ['advanc']},
#   43: {'text': 'expertise', 'lemmas': ['expertise'], 'stems': ['expertis']},
#   44: {'text': 'expert', 'lemmas': ['expert'], 'stems': ['expert']},
#   45: {'text': 'creativity', 'lemmas': ['creativity'], 'stems': ['creativ']},
#   46: {'text': 'spirit', 'lemmas': ['spirit'], 'stems': ['spirit']},
#   47: {'text': 'share', 'lemmas': ['share'], 'stems': ['share']},
#   48: {'text': 'post-industrial',
#    'lemmas': ['post', '-', 'industrial'],
#    'stems': ['post', '-', 'industri']},
#   49: {'text': 'different', 'lemmas': ['different'], 'stems': ['differ']},
#   50: {'text': 'deluge', 'lemmas': ['deluge'], 'stems': ['delug']},
#   51: {'text': 'organic', 'lemmas': ['organic'], 'stems': ['organ']},
#   52: {'text': 'factory', 'lemmas': ['factory'], 'stems': ['factori']},
#   53: {'text': 'flexibility', 'lemmas': ['flexibility'], 'stems': ['flexibl']},
#   54: {'text': 'variety', 'lemmas': ['variety'], 'stems': ['varieti']},
#   55: {'text': 'evolve', 'lemmas': ['evolve'], 'stems': ['evolv']},
#   56: {'text': 'idea', 'lemmas': ['idea'], 'stems': ['idea']},
#   57: {'text': 'cognitive', 'lemmas': ['cognitive'], 'stems': ['cognit']},
#   58: {'text': 'virtual', 'lemmas': ['virtual'], 'stems': ['virtual']},
#   59: {'text': 'personalization',
#    'lemmas': ['personalization'],
#    'stems': ['person']},
#   60: {'text': 'intelligence',
#    'lemmas': ['intelligence'],
#    'stems': ['intellig']},
#   61: {'text': 'community', 'lemmas': ['community'], 'stems': ['commun']},
#   62: {'text': 'practice', 'lemmas': ['practice'], 'stems': ['practic']},
#   63: {'text': 'integration', 'lemmas': ['integration'], 'stems': ['integr']},
#   64: {'text': 'cluster', 'lemmas': ['cluster'], 'stems': ['cluster']},
#   65: {'text': 'segments', 'lemmas': ['segment'], 'stems': ['segment']},
#   66: {'text': 'workgroup', 'lemmas': ['workgroup'], 'stems': ['workgroup']},
#   67: {'text': 'team', 'lemmas': ['team'], 'stems': ['team']},
#   68: {'text': 'interface', 'lemmas': ['interface'], 'stems': ['interfac']},
#   69: {'text': 'portfolio', 'lemmas': ['portfolio'], 'stems': ['portfolio']},
#   70: {'text': 'knowledge-based',
#    'lemmas': ['knowledge', '-', 'base'],
#    'stems': ['knowledg', '-', 'base']},
#   71: {'text': 'competence', 'lemmas': ['competence'], 'stems': ['compet']},
#   72: {'text': 'competencies', 'lemmas': ['competency'], 'stems': ['compet']},
#   73: {'text': 'competent', 'lemmas': ['competent'], 'stems': ['compet']},
#   74: {'text': 'versatile', 'lemmas': ['versatile'], 'stems': ['versatil']},
#   75: {'text': 'sharing', 'lemmas': ['share'], 'stems': ['share']},
#   76: {'text': 'experience', 'lemmas': ['experience'], 'stems': ['experi']},
#   77: {'text': 'co-locate',
#    'lemmas': ['co', '-', 'locate'],
#    'stems': ['co', '-', 'locat']},
#   78: {'text': 'co-location',
#    'lemmas': ['co', '-', 'location'],
#    'stems': ['co', '-', 'locat']},
#   79: {'text': 'seamless', 'lemmas': ['seamless'], 'stems': ['seamless']},
#   80: {'text': 'project', 'lemmas': ['project'], 'stems': ['project']},
#   81: {'text': 'convene', 'lemmas': ['convene'], 'stems': ['conven']},
#   82: {'text': 'disperse', 'lemmas': ['disperse'], 'stems': ['dispers']},
#   83: {'text': 'cycle', 'lemmas': ['cycle'], 'stems': ['cycl']},
#   84: {'text': 'accumulate', 'lemmas': ['accumulate'], 'stems': ['accumul']},
#   85: {'text': 'learning', 'lemmas': ['learn'], 'stems': ['learn']},
#   86: {'text': 'distribution',
#    'lemmas': ['distribution'],
#    'stems': ['distribut']},
#   87: {'text': 'closeness', 'lemmas': ['closeness'], 'stems': ['close']},
#   88: {'text': 'collaboration',
#    'lemmas': ['collaboration'],
#    'stems': ['collabor']},
#   89: {'text': 'customization',
#    'lemmas': ['customization'],
#    'stems': ['custom']},
#   90: {'text': 'reform', 'lemmas': ['reform'], 'stems': ['reform']},
#   91: {'text': 'reshape', 'lemmas': ['reshape'], 'stems': ['reshap']},
#   92: {'text': 'diverse', 'lemmas': ['diverse'], 'stems': ['divers']},
#   93: {'text': 'diverted', 'lemmas': ['divert'], 'stems': ['divert']}},
#  'Scope of Digital Business Strategy': {0: {'text': 'Scope',
#    'lemmas': ['scope'],
#    'stems': ['scope']},
#   1: {'text': 'fusion', 'lemmas': ['fusion'], 'stems': ['fusion']},
#   2: {'text': 'integration', 'lemmas': ['integration'], 'stems': ['integr']},
#   3: {'text': 'IT strategy',
#    'lemmas': ['it', 'strategy'],
#    'stems': ['it', 'strategi']},
#   4: {'text': 'barrier', 'lemmas': ['barrier'], 'stems': ['barrier']},
#   5: {'text': 'business strategy',
#    'lemmas': ['business', 'strategy'],
#    'stems': ['busi', 'strategi']},
#   6: {'text': 'encompassing', 'lemmas': ['encompass'], 'stems': ['encompass']},
#   7: {'text': 'transcend', 'lemmas': ['transcend'], 'stems': ['transcend']},
#   8: {'text': 'functional silo',
#    'lemmas': ['functional', 'silo'],
#    'stems': ['function', 'silo']},
#   9: {'text': 'process silo',
#    'lemmas': ['process', 'silo'],
#    'stems': ['process', 'silo']},
#   10: {'text': 'silo', 'lemmas': ['silo'], 'stems': ['silo']},
#   11: {'text': 'core', 'lemmas': ['core'], 'stems': ['core']},
#   12: {'text': 'exploit', 'lemmas': ['exploit'], 'stems': ['exploit']},
#   13: {'text': 'products', 'lemmas': ['product'], 'stems': ['product']},
#   14: {'text': 'product', 'lemmas': ['product'], 'stems': ['product']},
#   15: {'text': 'service', 'lemmas': ['service'], 'stems': ['servic']},
#   16: {'text': 'corporate', 'lemmas': ['corporate'], 'stems': ['corpor']},
#   17: {'text': 'portfolio', 'lemmas': ['portfolio'], 'stems': ['portfolio']},
#   18: {'text': 'control', 'lemmas': ['control'], 'stems': ['control']},
#   19: {'text': 'ownership', 'lemmas': ['ownership'], 'stems': ['ownership']},
#   20: {'text': 'diversification',
#    'lemmas': ['diversification'],
#    'stems': ['diversif']},
#   21: {'text': 'extend', 'lemmas': ['extend'], 'stems': ['extend']},
#   22: {'text': 'product reach',
#    'lemmas': ['product', 'reach'],
#    'stems': ['product', 'reach']},
#   23: {'text': 'market reach',
#    'lemmas': ['market', 'reach'],
#    'stems': ['market', 'reach']},
#   24: {'text': 'boundaries', 'lemmas': ['boundary'], 'stems': ['boundari']},
#   25: {'text': 'relationship',
#    'lemmas': ['relationship'],
#    'stems': ['relationship']},
#   26: {'text': 'environment', 'lemmas': ['environment'], 'stems': ['environ']},
#   27: {'text': 'competitive',
#    'lemmas': ['competitive'],
#    'stems': ['competit']},
#   28: {'text': 'cross-functional',
#    'lemmas': ['cross', '-', 'functional'],
#    'stems': ['cross', '-', 'function']},
#   29: {'text': 'transfunctional',
#    'lemmas': ['transfunctional'],
#    'stems': ['transfunct']},
#   30: {'text': 'multifunctional',
#    'lemmas': ['multifunctional'],
#    'stems': ['multifunct']},
#   31: {'text': 'multi-disciplinary',
#    'lemmas': ['multi', '-', 'disciplinary'],
#    'stems': ['multi', '-', 'disciplinari']},
#   32: {'text': 'cross-disciplinary',
#    'lemmas': ['cross', '-', 'disciplinary'],
#    'stems': ['cross', '-', 'disciplinari']},
#   33: {'text': 'IT-enabled business processes',
#    'lemmas': ['it', '-', 'enable', 'business', 'process'],
#    'stems': ['it', '-', 'enabl', 'busi', 'process']},
#   34: {'text': 'exchanges', 'lemmas': ['exchange'], 'stems': ['exchang']},
#   35: {'text': 'inside', 'lemmas': ['inside'], 'stems': ['insid']},
#   36: {'text': 'outside', 'lemmas': ['outside'], 'stems': ['outsid']},
#   37: {'text': 'interconnected',
#    'lemmas': ['interconnect'],
#    'stems': ['interconnect']},
#   38: {'text': 'broader', 'lemmas': ['broad'], 'stems': ['broader']},
#   39: {'text': 'embedded', 'lemmas': ['embed'], 'stems': ['embed']},
#   40: {'text': 'design', 'lemmas': ['design'], 'stems': ['design']},
#   41: {'text': 'interoperability',
#    'lemmas': ['interoperability'],
#    'stems': ['interoper']},
#   42: {'text': 'resource', 'lemmas': ['resource'], 'stems': ['resourc']},
#   43: {'text': 'linkage', 'lemmas': ['linkage'], 'stems': ['linkag']},
#   44: {'text': 'novel', 'lemmas': ['novel'], 'stems': ['novel']},
#   45: {'text': 'expand', 'lemmas': ['expand'], 'stems': ['expand']},
#   46: {'text': 'digitized product architecture',
#    'lemmas': ['digitize', 'product', 'architecture'],
#    'stems': ['digit', 'product', 'architectur']},
#   47: {'text': 'digital product architecture',
#    'lemmas': ['digital', 'product', 'architecture'],
#    'stems': ['digit', 'product', 'architectur']},
#   48: {'text': 'bits', 'lemmas': ['bit'], 'stems': ['bit']},
#   49: {'text': 'bytes', 'lemmas': ['byte'], 'stems': ['byte']},
#   50: {'text': 'protocols', 'lemmas': ['protocol'], 'stems': ['protocol']},
#   51: {'text': 'data', 'lemmas': ['datum'], 'stems': ['data']},
#   52: {'text': 'information', 'lemmas': ['information'], 'stems': ['inform']},
#   53: {'text': 'social media',
#    'lemmas': ['social', 'medium'],
#    'stems': ['social', 'media']},
#   54: {'text': 'big data',
#    'lemmas': ['big', 'datum'],
#    'stems': ['big', 'data']},
#   55: {'text': 'connectivity',
#    'lemmas': ['connectivity'],
#    'stems': ['connect']},
#   56: {'text': 'informationbased',
#    'lemmas': ['informationbase'],
#    'stems': ['informationbas']},
#   57: {'text': 'metrics', 'lemmas': ['metric'], 'stems': ['metric']},
#   58: {'text': 'hardware', 'lemmas': ['hardware'], 'stems': ['hardwar']},
#   59: {'text': 'software', 'lemmas': ['software'], 'stems': ['softwar']},
#   60: {'text': 'connected', 'lemmas': ['connect'], 'stems': ['connect']},
#   61: {'text': 'connections', 'lemmas': ['connection'], 'stems': ['connect']},
#   62: {'text': 'conditions', 'lemmas': ['condition'], 'stems': ['condit']},
#   63: {'text': 'supply Chain',
#    'lemmas': ['supply', 'chain'],
#    'stems': ['suppli', 'chain']},
#   64: {'text': 'supply network',
#    'lemmas': ['supply', 'network'],
#    'stems': ['suppli', 'network']},
#   65: {'text': 'intensive', 'lemmas': ['intensive'], 'stems': ['intens']},
#   66: {'text': 'alliances', 'lemmas': ['alliance'], 'stems': ['allianc']},
#   67: {'text': 'partnerships',
#    'lemmas': ['partnership'],
#    'stems': ['partnership']},
#   68: {'text': 'competitors',
#    'lemmas': ['competitor'],
#    'stems': ['competitor']},
#   69: {'text': 'spaces', 'lemmas': ['space'], 'stems': ['space']},
#   70: {'text': 'niches', 'lemmas': ['niche'], 'stems': ['nich']},
#   71: {'text': 'partners', 'lemmas': ['partner'], 'stems': ['partner']},
#   72: {'text': 'orchestration',
#    'lemmas': ['orchestration'],
#    'stems': ['orchestr']},
#   73: {'text': 'multifaceted',
#    'lemmas': ['multifacete'],
#    'stems': ['multifacet']},
#   74: {'text': 'rich', 'lemmas': ['rich'], 'stems': ['rich']},
#   75: {'text': 'dependency', 'lemmas': ['dependency'], 'stems': ['depend']},
#   76: {'text': 'coverage', 'lemmas': ['coverage'], 'stems': ['coverag']},
#   77: {'text': 'geographic', 'lemmas': ['geographic'], 'stems': ['geograph']},
#   78: {'text': 'syndicate', 'lemmas': ['syndicate'], 'stems': ['syndic']},
#   79: {'text': 'alliance', 'lemmas': ['alliance'], 'stems': ['allianc']}},
#  'Scale of Digital Business Strategy': {0: {'text': 'Scale',
#    'lemmas': ['scale'],
#    'stems': ['scale']},
#   1: {'text': 'rapidly', 'lemmas': ['rapidly'], 'stems': ['rapidli']},
#   2: {'text': 'effectively', 'lemmas': ['effectively'], 'stems': ['effect']},
#   3: {'text': 'infrastructure',
#    'lemmas': ['infrastructure'],
#    'stems': ['infrastructur']},
#   4: {'text': 'infrastructure',
#    'lemmas': ['infrastructure'],
#    'stems': ['infrastructur']},
#   5: {'text': 'Enable', 'lemmas': ['enable'], 'stems': ['enabl']},
#   6: {'text': 'bolster', 'lemmas': ['bolster'], 'stems': ['bolster']},
#   7: {'text': 'dynamic', 'lemmas': ['dynamic'], 'stems': ['dynam']},
#   8: {'text': 'network effects',
#    'lemmas': ['network', 'effect'],
#    'stems': ['network', 'effect']},
#   9: {'text': 'multisided', 'lemmas': ['multisided'], 'stems': ['multisid']},
#   10: {'text': 'abundance', 'lemmas': ['abundance'], 'stems': ['abund']},
#   11: {'text': 'volume', 'lemmas': ['volume'], 'stems': ['volum']},
#   12: {'text': 'cloud', 'lemmas': ['cloud'], 'stems': ['cloud']},
#   13: {'text': 'driver', 'lemmas': ['driver'], 'stems': ['driver']},
#   14: {'text': 'profitability',
#    'lemmas': ['profitability'],
#    'stems': ['profit']},
#   15: {'text': 'cost', 'lemmas': ['cost'], 'stems': ['cost']},
#   16: {'text': 'unit cost',
#    'lemmas': ['unit', 'cost'],
#    'stems': ['unit', 'cost']},
#   17: {'text': 'physical', 'lemmas': ['physical'], 'stems': ['physic']},
#   18: {'text': 'scale up',
#    'lemmas': ['scale', 'up'],
#    'stems': ['scale', 'up']},
#   19: {'text': 'scale down',
#    'lemmas': ['scale', 'down'],
#    'stems': ['scale', 'down']},
#   20: {'text': 'availability', 'lemmas': ['availability'], 'stems': ['avail']},
#   21: {'text': 'reliance', 'lemmas': ['reliance'], 'stems': ['relianc']},
#   22: {'text': 'on-demand',
#    'lemmas': ['on', '-', 'demand'],
#    'stems': ['on', '-', 'demand']},
#   23: {'text': 'shared', 'lemmas': ['share'], 'stems': ['share']},
#   24: {'text': 'configurable',
#    'lemmas': ['configurable'],
#    'stems': ['configur']},
#   25: {'text': 'computing', 'lemmas': ['compute'], 'stems': ['comput']},
#   26: {'text': 'self-service',
#    'lemmas': ['self', '-', 'service'],
#    'stems': ['self', '-', 'servic']},
#   27: {'text': 'virtualized', 'lemmas': ['virtualize'], 'stems': ['virtual']},
#   28: {'text': 'elastic', 'lemmas': ['elastic'], 'stems': ['elast']},
#   29: {'text': 'utilization', 'lemmas': ['utilization'], 'stems': ['util']},
#   30: {'text': 'access', 'lemmas': ['access'], 'stems': ['access']},
#   31: {'text': 'measure', 'lemmas': ['measure'], 'stems': ['measur']},
#   32: {'text': 'quality of service',
#    'lemmas': ['quality', 'of', 'service'],
#    'stems': ['qualiti', 'of', 'servic']},
#   33: {'text': 'operations', 'lemmas': ['operation'], 'stems': ['oper']},
#   34: {'text': 'functional', 'lemmas': ['functional'], 'stems': ['function']},
#   35: {'text': 'ability', 'lemmas': ['ability'], 'stems': ['abil']},
#   36: {'text': 'adapt', 'lemmas': ['adapt'], 'stems': ['adapt']},
#   37: {'text': 'requirement', 'lemmas': ['requirement'], 'stems': ['requir']},
#   38: {'text': 'marketplace',
#    'lemmas': ['marketplace'],
#    'stems': ['marketplac']},
#   39: {'text': 'pay-as-you-go',
#    'lemmas': ['pay', '-', 'as', '-', 'you', '-', 'go'],
#    'stems': ['pay', '-', 'as', '-', 'you', '-', 'go']},
#   40: {'text': 'pressure', 'lemmas': ['pressure'], 'stems': ['pressur']},
#   41: {'text': 'potential', 'lemmas': ['potential'], 'stems': ['potenti']},
#   42: {'text': 'interconnected',
#    'lemmas': ['interconnect'],
#    'stems': ['interconnect']},
#   43: {'text': 'partnerships',
#    'lemmas': ['partnership'],
#    'stems': ['partnership']},
#   44: {'text': 'interconnections',
#    'lemmas': ['interconnection'],
#    'stems': ['interconnect']},
#   45: {'text': 'web', 'lemmas': ['web'], 'stems': ['web']},
#   46: {'text': 'page', 'lemmas': ['page'], 'stems': ['page']},
#   47: {'text': 'broadband', 'lemmas': ['broadband'], 'stems': ['broadband']},
#   48: {'text': 'smart', 'lemmas': ['smart'], 'stems': ['smart']},
#   49: {'text': 'device', 'lemmas': ['device'], 'stems': ['devic']},
#   50: {'text': 'amplified', 'lemmas': ['amplify'], 'stems': ['amplifi']},
#   51: {'text': 'network', 'lemmas': ['network'], 'stems': ['network']},
#   52: {'text': 'abundance', 'lemmas': ['abundance'], 'stems': ['abund']},
#   53: {'text': 'internet of things',
#    'lemmas': ['internet', 'of', 'thing'],
#    'stems': ['internet', 'of', 'thing']},
#   54: {'text': 'IoT', 'lemmas': ['iot'], 'stems': ['iot']},
#   55: {'text': 'quantities', 'lemmas': ['quantity'], 'stems': ['quantiti']},
#   56: {'text': 'heterogeneous',
#    'lemmas': ['heterogeneous'],
#    'stems': ['heterogen']},
#   57: {'text': 'continuous', 'lemmas': ['continuous'], 'stems': ['continu']},
#   58: {'text': 'basis', 'lemmas': ['basis'], 'stems': ['basi']},
#   59: {'text': 'chatter', 'lemmas': ['chatter'], 'stems': ['chatter']},
#   60: {'text': 'social networks',
#    'lemmas': ['social', 'network'],
#    'stems': ['social', 'network']},
#   61: {'text': 'crowdsourcing',
#    'lemmas': ['crowdsource'],
#    'stems': ['crowdsourc']},
#   62: {'text': 'edge', 'lemmas': ['edge'], 'stems': ['edg']},
#   63: {'text': 'machine-to-machine',
#    'lemmas': ['machine', '-', 'to', '-', 'machine'],
#    'stems': ['machin', '-', 'to', '-', 'machin']},
#   64: {'text': 'sensor', 'lemmas': ['sensor'], 'stems': ['sensor']},
#   65: {'text': 'options', 'lemmas': ['option'], 'stems': ['option']},
#   66: {'text': 'crossselling',
#    'lemmas': ['crossselle'],
#    'stems': ['crosssel']},
#   67: {'text': 'cross-selling',
#    'lemmas': ['cross', '-', 'sell'],
#    'stems': ['cross', '-', 'sell']},
#   68: {'text': 'together', 'lemmas': ['together'], 'stems': ['togeth']},
#   69: {'text': 'digital setting',
#    'lemmas': ['digital', 'setting'],
#    'stems': ['digit', 'set']},
#   70: {'text': 'setting', 'lemmas': ['set'], 'stems': ['set']},
#   71: {'text': 'modularize', 'lemmas': ['modularize'], 'stems': ['modular']},
#   72: {'text': 'modul', 'lemmas': ['modul'], 'stems': ['modul']},
#   73: {'text': 'plug-and-play',
#    'lemmas': ['plug', '-', 'and', '-', 'play'],
#    'stems': ['plug', '-', 'and', '-', 'play']},
#   74: {'text': 'digital assets',
#    'lemmas': ['digital', 'asset'],
#    'stems': ['digit', 'asset']},
#   75: {'text': 'application programming interfaces',
#    'lemmas': ['application', 'programming', 'interface'],
#    'stems': ['applic', 'program', 'interfac']},
#   76: {'text': 'API', 'lemmas': ['API'], 'stems': ['api']},
#   77: {'text': 'web services',
#    'lemmas': ['web', 'service'],
#    'stems': ['web', 'servic']}},
#  'Speed of Digital Business Strategy': {0: {'text': 'Speed',
#    'lemmas': ['speed'],
#    'stems': ['speed']},
#   1: {'text': 'Dynamic', 'lemmas': ['dynamic'], 'stems': ['dynam']},
#   2: {'text': 'dynamism', 'lemmas': ['dynamism'], 'stems': ['dynam']},
#   3: {'text': 'accelerate', 'lemmas': ['accelerate'], 'stems': ['acceler']},
#   4: {'text': 'accelerating', 'lemmas': ['accelerate'], 'stems': ['acceler']},
#   5: {'text': 'product launch',
#    'lemmas': ['product', 'launch'],
#    'stems': ['product', 'launch']},
#   6: {'text': 'just-in-time',
#    'lemmas': ['just', '-', 'in', '-', 'time'],
#    'stems': ['just', '-', 'in', '-', 'time']},
#   7: {'text': 'launch', 'lemmas': ['launch'], 'stems': ['launch']},
#   8: {'text': 'learning', 'lemmas': ['learn'], 'stems': ['learn']},
#   9: {'text': 'improve', 'lemmas': ['improve'], 'stems': ['improv']},
#   10: {'text': 'improving', 'lemmas': ['improve'], 'stems': ['improv']},
#   11: {'text': 'decision-making',
#    'lemmas': ['decision', '-', 'making'],
#    'stems': ['decis', '-', 'make']},
#   12: {'text': 'decision', 'lemmas': ['decision'], 'stems': ['decis']},
#   13: {'text': 'bolster', 'lemmas': ['bolster'], 'stems': ['bolster']},
#   14: {'text': 'quickly', 'lemmas': ['quickly'], 'stems': ['quickli']},
#   15: {'text': 'quick', 'lemmas': ['quick'], 'stems': ['quick']},
#   16: {'text': 'formation', 'lemmas': ['formation'], 'stems': ['format']},
#   17: {'text': 'provide', 'lemmas': ['provide'], 'stems': ['provid']},
#   18: {'text': 'complementary',
#    'lemmas': ['complementary'],
#    'stems': ['complementari']},
#   19: {'text': 'sense', 'lemmas': ['sense'], 'stems': ['sens']},
#   20: {'text': 'respond', 'lemmas': ['respond'], 'stems': ['respond']},
#   21: {'text': 'cycle', 'lemmas': ['cycle'], 'stems': ['cycl']},
#   22: {'text': 'real-time',
#    'lemmas': ['real', '-', 'time'],
#    'stems': ['real', '-', 'time']},
#   23: {'text': 'time', 'lemmas': ['time'], 'stems': ['time']},
#   24: {'text': 'timely', 'lemmas': ['timely'], 'stems': ['time']},
#   25: {'text': 'central', 'lemmas': ['central'], 'stems': ['central']},
#   26: {'text': 'pervasive', 'lemmas': ['pervasive'], 'stems': ['pervas']},
#   27: {'text': 'series', 'lemmas': ['series'], 'stems': ['seri']},
#   28: {'text': 'improvement', 'lemmas': ['improvement'], 'stems': ['improv']},
#   29: {'text': 'hybrid', 'lemmas': ['hybrid'], 'stems': ['hybrid']},
#   30: {'text': 'product introduction',
#    'lemmas': ['product', 'introduction'],
#    'stems': ['product', 'introduct']},
#   31: {'text': 'introduction',
#    'lemmas': ['introduction'],
#    'stems': ['introduct']},
#   32: {'text': 'initiative', 'lemmas': ['initiative'], 'stems': ['initi']},
#   33: {'text': 'add', 'lemmas': ['add'], 'stems': ['add']},
#   34: {'text': 'dimension', 'lemmas': ['dimension'], 'stems': ['dimens']},
#   35: {'text': 'clock', 'lemmas': ['clock'], 'stems': ['clock']},
#   36: {'text': 'recalibrate',
#    'lemmas': ['recalibrate'],
#    'stems': ['recalibr']},
#   37: {'text': 'calibrate', 'lemmas': ['calibrate'], 'stems': ['calibr']},
#   38: {'text': 'predictable', 'lemmas': ['predictable'], 'stems': ['predict']},
#   39: {'text': 'improvement', 'lemmas': ['improvement'], 'stems': ['improv']},
#   40: {'text': 'functionality',
#    'lemmas': ['functionality'],
#    'stems': ['function']},
#   41: {'text': 'multiyear', 'lemmas': ['multiyear'], 'stems': ['multiyear']},
#   42: {'text': 'sequence', 'lemmas': ['sequence'], 'stems': ['sequenc']},
#   43: {'text': 'remain', 'lemmas': ['remain'], 'stems': ['remain']},
#   44: {'text': 'decade', 'lemmas': ['decade'], 'stems': ['decad']},
#   45: {'text': 'recent', 'lemmas': ['recent'], 'stems': ['recent']},
#   46: {'text': 'combine', 'lemmas': ['combine'], 'stems': ['combin']},
#   47: {'text': 'bandwidth', 'lemmas': ['bandwidth'], 'stems': ['bandwidth']},
#   48: {'text': 'mobile', 'lemmas': ['mobile'], 'stems': ['mobil']},
#   49: {'text': 'plan', 'lemmas': ['plan'], 'stems': ['plan']},
#   50: {'text': 'planned', 'lemmas': ['plan'], 'stems': ['plan']},
#   51: {'text': 'obsolescence',
#    'lemmas': ['obsolescence'],
#    'stems': ['obsolesc']},
#   52: {'text': 'recognize', 'lemmas': ['recognize'], 'stems': ['recogn']},
#   53: {'text': 'respond', 'lemmas': ['respond'], 'stems': ['respond']},
#   54: {'text': 'fast-paced',
#    'lemmas': ['fast', '-', 'pace'],
#    'stems': ['fast', '-', 'pace']},
#   55: {'text': 'pace', 'lemmas': ['pace'], 'stems': ['pace']},
#   56: {'text': 'innovation', 'lemmas': ['innovation'], 'stems': ['innov']},
#   57: {'text': 'implementation',
#    'lemmas': ['implementation'],
#    'stems': ['implement']},
#   58: {'text': 'fundamental',
#    'lemmas': ['fundamental'],
#    'stems': ['fundament']},
#   59: {'text': 'competitive',
#    'lemmas': ['competitive'],
#    'stems': ['competit']},
#   60: {'text': 'success', 'lemmas': ['success'], 'stems': ['success']},
#   61: {'text': 'survival', 'lemmas': ['survival'], 'stems': ['surviv']},
#   62: {'text': 'coordination',
#    'lemmas': ['coordination'],
#    'stems': ['coordin']},
#   63: {'text': 'control', 'lemmas': ['control'], 'stems': ['control']},
#   64: {'text': 'standalone', 'lemmas': ['standalone'], 'stems': ['standalon']},
#   65: {'text': 'autonomous', 'lemmas': ['autonomous'], 'stems': ['autonom']},
#   66: {'text': 'availability', 'lemmas': ['availability'], 'stems': ['avail']},
#   67: {'text': 'slow', 'lemmas': ['slow'], 'stems': ['slow']},
#   68: {'text': 'slowness', 'lemmas': ['slowness'], 'stems': ['slow']},
#   69: {'text': 'flow', 'lemmas': ['flow'], 'stems': ['flow']},
#   70: {'text': 'hierarchy', 'lemmas': ['hierarchy'], 'stems': ['hierarchi']},
#   71: {'text': 'multiple', 'lemmas': ['multiple'], 'stems': ['multipl']},
#   72: {'text': 'layer', 'lemmas': ['layer'], 'stems': ['layer']},
#   73: {'text': 'stream', 'lemmas': ['stream'], 'stems': ['stream']},
#   74: {'text': 'focal', 'lemmas': ['focal'], 'stems': ['focal']},
#   75: {'text': 'partners', 'lemmas': ['partner'], 'stems': ['partner']},
#   76: {'text': 'allies', 'lemmas': ['ally'], 'stems': ['alli']},
#   77: {'text': 'responding', 'lemmas': ['respond'], 'stems': ['respond']},
#   78: {'text': 'customer service',
#    'lemmas': ['customer', 'service'],
#    'stems': ['custom', 'servic']},
#   79: {'text': 'request', 'lemmas': ['request'], 'stems': ['request']},
#   80: {'text': 'Twitter', 'lemmas': ['twitter'], 'stems': ['twitter']},
#   81: {'text': 'Facebook', 'lemmas': ['Facebook'], 'stems': ['facebook']},
#   82: {'text': 'social media',
#    'lemmas': ['social', 'medium'],
#    'stems': ['social', 'media']},
#   83: {'text': 'move', 'lemmas': ['move'], 'stems': ['move']},
#   84: {'text': 'tune', 'lemmas': ['tune'], 'stems': ['tune']},
#   85: {'text': 'reality', 'lemmas': ['reality'], 'stems': ['realiti']},
#   86: {'text': 'variety', 'lemmas': ['variety'], 'stems': ['varieti']},
#   87: {'text': 'experiment', 'lemmas': ['experiment'], 'stems': ['experi']},
#   88: {'text': 'integrative', 'lemmas': ['integrative'], 'stems': ['integr']},
#   89: {'text': 'command', 'lemmas': ['command'], 'stems': ['command']},
#   90: {'text': 'organize', 'lemmas': ['organize'], 'stems': ['organ']},
#   91: {'text': 'analyze', 'lemmas': ['analyze'], 'stems': ['analyz']},
#   92: {'text': 'analytic', 'lemmas': ['analytic'], 'stems': ['analyt']},
#   93: {'text': 'analysis', 'lemmas': ['analysis'], 'stems': ['analysi']},
#   94: {'text': 'accumulate', 'lemmas': ['accumulate'], 'stems': ['accumul']},
#   95: {'text': 'transaction',
#    'lemmas': ['transaction'],
#    'stems': ['transact']},
#   96: {'text': 'elapse', 'lemmas': ['elapse'], 'stems': ['elaps']},
#   97: {'text': 'correspond',
#    'lemmas': ['correspond'],
#    'stems': ['correspond']},
#   98: {'text': 'wave', 'lemmas': ['wave'], 'stems': ['wave']},
#   99: {'text': 'redesign', 'lemmas': ['redesign'], 'stems': ['redesign']},
#   100: {'text': 'effective', 'lemmas': ['effective'], 'stems': ['effect']},
#   101: {'text': 'end-to-end',
#    'lemmas': ['end', '-', 'to', '-', 'end'],
#    'stems': ['end', '-', 'to', '-', 'end']},
#   102: {'text': 'visibility', 'lemmas': ['visibility'], 'stems': ['visibl']},
#   103: {'text': 'efficient', 'lemmas': ['efficient'], 'stems': ['effici']},
#   104: {'text': 'coupled', 'lemmas': ['couple'], 'stems': ['coupl']},
#   105: {'text': 'outsourcing', 'lemmas': ['outsource'], 'stems': ['outsourc']},
#   106: {'text': 'non-core',
#    'lemmas': ['non', '-', 'core'],
#    'stems': ['non', '-', 'core']},
#   107: {'text': 'interfirm', 'lemmas': ['interfirm'], 'stems': ['interfirm']},
#   108: {'text': 'announcing', 'lemmas': ['announce'], 'stems': ['announc']},
#   109: {'text': 'announce', 'lemmas': ['announce'], 'stems': ['announc']},
#   110: {'text': 'first-mover',
#    'lemmas': ['first', '-', 'mover'],
#    'stems': ['first', '-', 'mover']},
#   111: {'text': 'global', 'lemmas': ['global'], 'stems': ['global']},
#   112: {'text': 'non-value',
#    'lemmas': ['non', '-', 'value'],
#    'stems': ['non', '-', 'valu']},
#   113: {'text': 'collaborative',
#    'lemmas': ['collaborative'],
#    'stems': ['collabor']},
#   114: {'text': 'conceptual', 'lemmas': ['conceptual'], 'stems': ['conceptu']},
#   115: {'text': 'tomorrow', 'lemmas': ['tomorrow'], 'stems': ['tomorrow']},
#   116: {'text': 'realignment',
#    'lemmas': ['realignment'],
#    'stems': ['realign']},
#   117: {'text': 'adaptation', 'lemmas': ['adaptation'], 'stems': ['adapt']},
#   118: {'text': 'apps', 'lemmas': ['app'], 'stems': ['app']},
#   119: {'text': 'insights', 'lemmas': ['insight'], 'stems': ['insight']}},
#  'Sources of Value Creation and Capture': {0: {'text': 'Source',
#    'lemmas': ['source'],
#    'stems': ['sourc']},
#   1: {'text': 'Resource', 'lemmas': ['resource'], 'stems': ['resourc']},
#   2: {'text': 'capability', 'lemmas': ['capability'], 'stems': ['capabl']},
#   3: {'text': 'value', 'lemmas': ['value'], 'stems': ['valu']},
#   4: {'text': 'capture', 'lemmas': ['capture'], 'stems': ['captur']},
#   5: {'text': 'leveraging', 'lemmas': ['leverage'], 'stems': ['leverag']},
#   6: {'text': 'leverage', 'lemmas': ['leverage'], 'stems': ['leverag']},
#   7: {'text': 'business models',
#    'lemmas': ['business', 'model'],
#    'stems': ['busi', 'model']},
#   8: {'text': 'capturing', 'lemmas': ['capture'], 'stems': ['captur']},
#   9: {'text': 'appropriating',
#    'lemmas': ['appropriate'],
#    'stems': ['appropri']},
#   10: {'text': 'appropriation',
#    'lemmas': ['appropriation'],
#    'stems': ['appropri']},
#   11: {'text': 'architecture',
#    'lemmas': ['architecture'],
#    'stems': ['architectur']},
#   12: {'text': 'profitability',
#    'lemmas': ['profitability'],
#    'stems': ['profit']},
#   13: {'text': 'value creation',
#    'lemmas': ['value', 'creation'],
#    'stems': ['valu', 'creation']},
#   14: {'text': 'value capture',
#    'lemmas': ['value', 'capture'],
#    'stems': ['valu', 'captur']},
#   15: {'text': 'value proposition',
#    'lemmas': ['value', 'proposition'],
#    'stems': ['valu', 'proposit']},
#   16: {'text': 'sustainability',
#    'lemmas': ['sustainability'],
#    'stems': ['sustain']},
#   17: {'text': 'robust', 'lemmas': ['robust'], 'stems': ['robust']},
#   18: {'text': 'intangible', 'lemmas': ['intangible'], 'stems': ['intang']},
#   19: {'text': 'opportunities',
#    'lemmas': ['opportunity'],
#    'stems': ['opportun']},
#   20: {'text': 'fundamental',
#    'lemmas': ['fundamental'],
#    'stems': ['fundament']},
#   21: {'text': 'rethink', 'lemmas': ['rethink'], 'stems': ['rethink']},
#   22: {'text': 'unique', 'lemmas': ['unique'], 'stems': ['uniqu']},
#   23: {'text': 'curating', 'lemmas': ['curate'], 'stems': ['curat']},
#   24: {'text': 'content', 'lemmas': ['content'], 'stems': ['content']},
#   25: {'text': 'assess', 'lemmas': ['assess'], 'stems': ['assess']},
#   26: {'text': 'balance', 'lemmas': ['balance'], 'stems': ['balanc']},
#   27: {'text': 'subscription',
#    'lemmas': ['subscription'],
#    'stems': ['subscript']},
#   28: {'text': 'advertising',
#    'lemmas': ['advertising'],
#    'stems': ['advertis']},
#   29: {'text': 'financial', 'lemmas': ['financial'], 'stems': ['financi']},
#   30: {'text': 'accurate', 'lemmas': ['accurate'], 'stems': ['accur']},
#   31: {'text': 'fine-tune',
#    'lemmas': ['fine', '-', 'tune'],
#    'stems': ['fine', '-', 'tune']},
#   32: {'text': 'personalize', 'lemmas': ['personalize'], 'stems': ['person']},
#   33: {'text': 'offerings', 'lemmas': ['offering'], 'stems': ['offer']},
#   34: {'text': 'preferences', 'lemmas': ['preference'], 'stems': ['prefer']},
#   35: {'text': 'democratization',
#    'lemmas': ['democratization'],
#    'stems': ['democrat']},
#   36: {'text': 'content', 'lemmas': ['content'], 'stems': ['content']},
#   37: {'text': 'sharing', 'lemmas': ['share'], 'stems': ['share']},
#   38: {'text': 'remixing', 'lemmas': ['remixe'], 'stems': ['remix']},
#   39: {'text': 'redistribution',
#    'lemmas': ['redistribution'],
#    'stems': ['redistribut']},
#   40: {'text': 'resyndication',
#    'lemmas': ['resyndication'],
#    'stems': ['resynd']},
#   41: {'text': 'dramatic', 'lemmas': ['dramatic'], 'stems': ['dramat']},
#   42: {'text': 'power', 'lemmas': ['power'], 'stems': ['power']},
#   43: {'text': 'shifts', 'lemmas': ['shift'], 'stems': ['shift']},
#   44: {'text': 'channel', 'lemmas': ['channel'], 'stems': ['channel']},
#   45: {'text': 'disintermediation',
#    'lemmas': ['disintermediation'],
#    'stems': ['disintermedi']},
#   46: {'text': 'disrupt', 'lemmas': ['disrupt'], 'stems': ['disrupt']},
#   47: {'text': 'sharp', 'lemmas': ['sharp'], 'stems': ['sharp']},
#   48: {'text': 'importance', 'lemmas': ['importance'], 'stems': ['import']},
#   49: {'text': 'revenue', 'lemmas': ['revenue'], 'stems': ['revenu']},
#   50: {'text': 'free', 'lemmas': ['free'], 'stems': ['free']},
#   51: {'text': 'monetizing', 'lemmas': ['monetize'], 'stems': ['monet']},
#   52: {'text': 'influence', 'lemmas': ['influence'], 'stems': ['influenc']},
#   53: {'text': 'nuanced', 'lemmas': ['nuance'], 'stems': ['nuanc']},
#   54: {'text': 'conceptualize',
#    'lemmas': ['conceptualize'],
#    'stems': ['conceptu']},
#   55: {'text': 'interactions',
#    'lemmas': ['interaction'],
#    'stems': ['interact']},
#   56: {'text': 'logical', 'lemmas': ['logical'], 'stems': ['logic']},
#   57: {'text': 'recognition',
#    'lemmas': ['recognition'],
#    'stems': ['recognit']},
#   58: {'text': 'quality', 'lemmas': ['quality'], 'stems': ['qualiti']},
#   59: {'text': 'involve', 'lemmas': ['involve'], 'stems': ['involv']},
#   60: {'text': 'complex', 'lemmas': ['complex'], 'stems': ['complex']},
#   61: {'text': 'cocreate', 'lemmas': ['cocreate'], 'stems': ['cocreat']},
#   62: {'text': 'complicating', 'lemmas': ['complicate'], 'stems': ['complic']},
#   63: {'text': 'factor', 'lemmas': ['factor'], 'stems': ['factor']},
#   64: {'text': 'independent',
#    'lemmas': ['independent'],
#    'stems': ['independ']},
#   65: {'text': 'intersect', 'lemmas': ['intersect'], 'stems': ['intersect']},
#   66: {'text': 'interoperate',
#    'lemmas': ['interoperate'],
#    'stems': ['interoper']},
#   67: {'text': 'players', 'lemmas': ['player'], 'stems': ['player']},
#   68: {'text': 'rich', 'lemmas': ['rich'], 'stems': ['rich']},
#   69: {'text': 'richer', 'lemmas': ['rich'], 'stems': ['richer']},
#   70: {'text': 'delineate', 'lemmas': ['delineate'], 'stems': ['delin']},
#   71: {'text': 'evolve', 'lemmas': ['evolve'], 'stems': ['evolv']},
#   72: {'text': 'market share',
#    'lemmas': ['market', 'share'],
#    'stems': ['market', 'share']},
#   73: {'text': 'lead', 'lemmas': ['lead'], 'stems': ['lead']},
#   74: {'text': 'earn', 'lemmas': ['earn'], 'stems': ['earn']},
#   75: {'text': 'receive', 'lemmas': ['receive'], 'stems': ['receiv']},
#   76: {'text': 'follow-on',
#    'lemmas': ['follow', '-', 'on'],
#    'stems': ['follow', '-', 'on']},
#   77: {'text': 'extract', 'lemmas': ['extract'], 'stems': ['extract']},
#   78: {'text': 'high', 'lemmas': ['high'], 'stems': ['high']},
#   79: {'text': 'premium', 'lemmas': ['premium'], 'stems': ['premium']},
#   80: {'text': 'indication', 'lemmas': ['indication'], 'stems': ['indic']},
#   81: {'text': 'redefine', 'lemmas': ['redefine'], 'stems': ['redefin']},
#   82: {'text': 'disproportionate',
#    'lemmas': ['disproportionate'],
#    'stems': ['disproportion']},
#   83: {'text': 'position', 'lemmas': ['position'], 'stems': ['posit']},
#   84: {'text': 'metrics', 'lemmas': ['metric'], 'stems': ['metric']},
#   85: {'text': 'track', 'lemmas': ['track'], 'stems': ['track']},
#   86: {'text': 'follow', 'lemmas': ['follow'], 'stems': ['follow']},
#   87: {'text': 'performance', 'lemmas': ['performance'], 'stems': ['perform']},
#   88: {'text': 'important', 'lemmas': ['important'], 'stems': ['import']},
#   89: {'text': 'question', 'lemmas': ['question'], 'stems': ['question']},
#   90: {'text': 'formulate', 'lemmas': ['formulate'], 'stems': ['formul']},
#   91: {'text': 'execute', 'lemmas': ['execute'], 'stems': ['execut']},
#   92: {'text': 'differential',
#    'lemmas': ['differential'],
#    'stems': ['differenti']},
#   93: {'text': 'differenc', 'lemmas': ['differenc'], 'stems': ['differenc']}}}
