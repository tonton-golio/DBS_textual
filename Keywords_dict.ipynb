# %% [markdown]
# # Keywords dictionary

# %% [markdown]
# ### Imports and function definitions

# %%
import numpy as np  # for saving dictionary at the end 

import spacy  # for lemmanizing
nlp = spacy.load('en_core_web_sm')  # here we could easily use a bigger model

from nltk.stem import PorterStemmer  # for stemming
ps = PorterStemmer()  # this can also be changed out for other prebuilts

def remove_trailing_spaces(string):
    '''simple while loop for removing trailing spaces. returns string less trailing spaces.'''
    while string[-1] == ' ':
        string = string[:-1]
        
    return string

# %% [markdown]
# ### Load text and place in dictionary

# %%
filename = 'data/dictionary_v2.txt'  
# load keywords from text file. Assumes entries are line seperated and categories are seperate by 3 lines
with open(filename) as f:
    text=f.read()[:-1]

# %%
lst = [i.split('\n') for i in text.split('\n\n\n')]

dic = {}
for i in lst:
    dic[i[0]] = {}
    for index, word in enumerate(i[1:]):
        dic[i[0]][index]= {'text': remove_trailing_spaces(word)}

# %% [markdown]
# ### Stemming and Lemmanizing

# %%
for key in dic.keys():
    for key2 in dic[key].keys():
        doc = nlp(dic[key][key2]['text'])
        lemmas = [word.lemma_ for word in doc]
        dic[key][key2]['lemmas'] = lemmas
        stems = [ps.stem(str(word)) for word in doc]
        dic[key][key2]['stems'] = stems
[(key, len(list(dic[key]))) for key in dic.keys()]
# Out:
# [('DBS', 97),
#  ('Scope of Digital Business Strategy', 88),
#  ('Scale of Digital Business Strategy', 77),
#  ('Speed of Digital Business Strategy', 116),
#  ('Sources of Value Creation and Capture', 91)]

# %% [markdown]
# ### Save dict

# %%
np.savez('data/keywords_dict.npz', dic)

# %%
file = np.load('data/keywords_dict.npz', allow_pickle=1)
dic_loaded = file[file.files[0]].item()

# %%
dic_loaded
# Out:
# {'DBS': {0: {'text': 'Digital technology',
#    'lemmas': ['Digital', 'technology'],
#    'stems': ['digit', 'technolog']},
#   1: {'text': 'Digital era',
#    'lemmas': ['Digital', 'era'],
#    'stems': ['digit', 'era']},
#   2: {'text': 'Digital resources',
#    'lemmas': ['Digital', 'resource'],
#    'stems': ['digit', 'resourc']},
#   3: {'text': 'Platform', 'lemmas': ['platform'], 'stems': ['platform']},
#   4: {'text': 'Recombination/Integration',
#    'lemmas': ['Recombination', '/', 'integration'],
#    'stems': ['recombin', '/', 'integr']},
#   5: {'text': 'Recombination',
#    'lemmas': ['recombination'],
#    'stems': ['recombin']},
#   6: {'text': 'Combination', 'lemmas': ['combination'], 'stems': ['combin']},
#   7: {'text': 'Combining', 'lemmas': ['combine'], 'stems': ['combin']},
#   8: {'text': 'combine', 'lemmas': ['combine'], 'stems': ['combin']},
#   9: {'text': 'coupling', 'lemmas': ['couple'], 'stems': ['coupl']},
#   10: {'text': 'decoupling', 'lemmas': ['decouple'], 'stems': ['decoupl']},
#   11: {'text': 'recoupling', 'lemmas': ['recouple'], 'stems': ['recoupl']},
#   12: {'text': 'continuum', 'lemmas': ['continuum'], 'stems': ['continuum']},
#   13: {'text': 'domino', 'lemmas': ['domino'], 'stems': ['domino']},
#   14: {'text': 'transcend', 'lemmas': ['transcend'], 'stems': ['transcend']},
#   15: {'text': 'loyalty', 'lemmas': ['loyalty'], 'stems': ['loyalti']},
#   16: {'text': 'harmony', 'lemmas': ['harmony'], 'stems': ['harmoni']},
#   17: {'text': 'solution', 'lemmas': ['solution'], 'stems': ['solut']},
#   18: {'text': 'problem setting',
#    'lemmas': ['problem', 'set'],
#    'stems': ['problem', 'set']},
#   19: {'text': 'connotation', 'lemmas': ['connotation'], 'stems': ['connot']},
#   20: {'text': 'solidarity', 'lemmas': ['solidarity'], 'stems': ['solidar']},
#   21: {'text': 'overcoming limits',
#    'lemmas': ['overcome', 'limit'],
#    'stems': ['overcom', 'limit']},
#   22: {'text': 'knowledge', 'lemmas': ['knowledge'], 'stems': ['knowledg']},
#   23: {'text': 'skills', 'lemmas': ['skill'], 'stems': ['skill']},
#   24: {'text': 'skilled', 'lemmas': ['skilled'], 'stems': ['skill']},
#   25: {'text': 'experience', 'lemmas': ['experience'], 'stems': ['experi']},
#   26: {'text': 'complexity', 'lemmas': ['complexity'], 'stems': ['complex']},
#   27: {'text': 'hyper', 'lemmas': ['hyper'], 'stems': ['hyper']},
#   28: {'text': 'react', 'lemmas': ['react'], 'stems': ['react']},
#   29: {'text': 'continuous', 'lemmas': ['continuous'], 'stems': ['continu']},
#   30: {'text': 'change', 'lemmas': ['change'], 'stems': ['chang']},
#   31: {'text': 'agility', 'lemmas': ['agility'], 'stems': ['agil']},
#   32: {'text': 'agile', 'lemmas': ['agile'], 'stems': ['agil']},
#   33: {'text': 'generic', 'lemmas': ['generic'], 'stems': ['gener']},
#   34: {'text': 'quality', 'lemmas': ['quality'], 'stems': ['qualiti']},
#   35: {'text': 'flexibility', 'lemmas': ['flexibility'], 'stems': ['flexibl']},
#   36: {'text': 'leadership',
#    'lemmas': ['leadership'],
#    'stems': ['leadership']},
#   37: {'text': 'learning', 'lemmas': ['learn'], 'stems': ['learn']},
#   38: {'text': 'acumen', 'lemmas': ['acuman'], 'stems': ['acumen']},
#   39: {'text': 'niche', 'lemmas': ['niche'], 'stems': ['nich']},
#   40: {'text': 'multiplicity',
#    'lemmas': ['multiplicity'],
#    'stems': ['multipl']},
#   41: {'text': 'choice', 'lemmas': ['choice'], 'stems': ['choic']},
#   42: {'text': 'savvy', 'lemmas': ['savvy'], 'stems': ['savvi']},
#   43: {'text': 'informed', 'lemmas': ['inform'], 'stems': ['inform']},
#   44: {'text': 'proliferation',
#    'lemmas': ['proliferation'],
#    'stems': ['prolifer']},
#   45: {'text': 'advancement', 'lemmas': ['advancement'], 'stems': ['advanc']},
#   46: {'text': 'expertise', 'lemmas': ['expertise'], 'stems': ['expertis']},
#   47: {'text': 'expert', 'lemmas': ['expert'], 'stems': ['expert']},
#   48: {'text': 'creativity', 'lemmas': ['creativity'], 'stems': ['creativ']},
#   49: {'text': 'spirit', 'lemmas': ['spirit'], 'stems': ['spirit']},
#   50: {'text': 'share', 'lemmas': ['share'], 'stems': ['share']},
#   51: {'text': 'post-industrial',
#    'lemmas': ['post', '-', 'industrial'],
#    'stems': ['post', '-', 'industri']},
#   52: {'text': 'different', 'lemmas': ['different'], 'stems': ['differ']},
#   53: {'text': 'deluge', 'lemmas': ['deluge'], 'stems': ['delug']},
#   54: {'text': 'organic', 'lemmas': ['organic'], 'stems': ['organ']},
#   55: {'text': 'knowledge factory',
#    'lemmas': ['knowledge', 'factory'],
#    'stems': ['knowledg', 'factori']},
#   56: {'text': 'flexibility', 'lemmas': ['flexibility'], 'stems': ['flexibl']},
#   57: {'text': 'variety', 'lemmas': ['variety'], 'stems': ['varieti']},
#   58: {'text': 'evolve', 'lemmas': ['evolve'], 'stems': ['evolv']},
#   59: {'text': 'idea', 'lemmas': ['idea'], 'stems': ['idea']},
#   60: {'text': 'cognitive', 'lemmas': ['cognitive'], 'stems': ['cognit']},
#   61: {'text': 'virtual', 'lemmas': ['virtual'], 'stems': ['virtual']},
#   62: {'text': 'personalization',
#    'lemmas': ['personalization'],
#    'stems': ['person']},
#   63: {'text': 'intelligence',
#    'lemmas': ['intelligence'],
#    'stems': ['intellig']},
#   64: {'text': 'community', 'lemmas': ['community'], 'stems': ['commun']},
#   65: {'text': 'practice', 'lemmas': ['practice'], 'stems': ['practic']},
#   66: {'text': 'integration', 'lemmas': ['integration'], 'stems': ['integr']},
#   67: {'text': 'cluster', 'lemmas': ['cluster'], 'stems': ['cluster']},
#   68: {'text': 'segments', 'lemmas': ['segment'], 'stems': ['segment']},
#   69: {'text': 'workgroup', 'lemmas': ['workgroup'], 'stems': ['workgroup']},
#   70: {'text': 'team', 'lemmas': ['team'], 'stems': ['team']},
#   71: {'text': 'interface', 'lemmas': ['interface'], 'stems': ['interfac']},
#   72: {'text': 'portfolio', 'lemmas': ['portfolio'], 'stems': ['portfolio']},
#   73: {'text': 'knowledge-based',
#    'lemmas': ['knowledge', '-', 'base'],
#    'stems': ['knowledg', '-', 'base']},
#   74: {'text': 'competence', 'lemmas': ['competence'], 'stems': ['compet']},
#   75: {'text': 'competencies', 'lemmas': ['competency'], 'stems': ['compet']},
#   76: {'text': 'competent', 'lemmas': ['competent'], 'stems': ['compet']},
#   77: {'text': 'versatile', 'lemmas': ['versatile'], 'stems': ['versatil']},
#   78: {'text': 'sharing', 'lemmas': ['share'], 'stems': ['share']},
#   79: {'text': 'experience', 'lemmas': ['experience'], 'stems': ['experi']},
#   80: {'text': 'co-locate',
#    'lemmas': ['co', '-', 'locate'],
#    'stems': ['co', '-', 'locat']},
#   81: {'text': 'co-location',
#    'lemmas': ['co', '-', 'location'],
#    'stems': ['co', '-', 'locat']},
#   82: {'text': 'seamless', 'lemmas': ['seamless'], 'stems': ['seamless']},
#   83: {'text': 'project', 'lemmas': ['project'], 'stems': ['project']},
#   84: {'text': 'convene', 'lemmas': ['convene'], 'stems': ['conven']},
#   85: {'text': 'disperse', 'lemmas': ['disperse'], 'stems': ['dispers']},
#   86: {'text': 'cycle', 'lemmas': ['cycle'], 'stems': ['cycl']},
#   87: {'text': 'accumulate', 'lemmas': ['accumulate'], 'stems': ['accumul']},
#   88: {'text': 'learning', 'lemmas': ['learn'], 'stems': ['learn']},
#   89: {'text': 'distribution',
#    'lemmas': ['distribution'],
#    'stems': ['distribut']},
#   90: {'text': 'closeness', 'lemmas': ['closeness'], 'stems': ['close']},
#   91: {'text': 'collaboration',
#    'lemmas': ['collaboration'],
#    'stems': ['collabor']},
#   92: {'text': 'customization',
#    'lemmas': ['customization'],
#    'stems': ['custom']},
#   93: {'text': 'reform', 'lemmas': ['reform'], 'stems': ['reform']},
#   94: {'text': 'reshape', 'lemmas': ['reshape'], 'stems': ['reshap']},
#   95: {'text': 'diverse', 'lemmas': ['diverse'], 'stems': ['divers']},
#   96: {'text': 'diverted', 'lemmas': ['divert'], 'stems': ['divert']}},
#  'Scope of Digital Business Strategy': {0: {'text': 'Scope',
#    'lemmas': ['scope'],
#    'stems': ['scope']},
#   1: {'text': 'fusion', 'lemmas': ['fusion'], 'stems': ['fusion']},
#   2: {'text': 'integration', 'lemmas': ['integration'], 'stems': ['integr']},
#   3: {'text': 'IT strategy',
#    'lemmas': ['it', 'strategy'],
#    'stems': ['it', 'strategi']},
#   4: {'text': 'barrier', 'lemmas': ['barrier'], 'stems': ['barrier']},
#   5: {'text': 'business strategy',
#    'lemmas': ['business', 'strategy'],
#    'stems': ['busi', 'strategi']},
#   6: {'text': 'encompassing', 'lemmas': ['encompass'], 'stems': ['encompass']},
#   7: {'text': 'transcend', 'lemmas': ['transcend'], 'stems': ['transcend']},
#   8: {'text': 'functional silo',
#    'lemmas': ['functional', 'silo'],
#    'stems': ['function', 'silo']},
#   9: {'text': 'process silo',
#    'lemmas': ['process', 'silo'],
#    'stems': ['process', 'silo']},
#   10: {'text': 'silo', 'lemmas': ['silo'], 'stems': ['silo']},
#   11: {'text': 'core', 'lemmas': ['core'], 'stems': ['core']},
#   12: {'text': 'exploit', 'lemmas': ['exploit'], 'stems': ['exploit']},
#   13: {'text': 'digitization of products',
#    'lemmas': ['digitization', 'of', 'product'],
#    'stems': ['digit', 'of', 'product']},
#   14: {'text': 'digital product',
#    'lemmas': ['digital', 'product'],
#    'stems': ['digit', 'product']},
#   15: {'text': 'digital service',
#    'lemmas': ['digital', 'service'],
#    'stems': ['digit', 'servic']},
#   16: {'text': 'digitization of service',
#    'lemmas': ['digitization', 'of', 'service'],
#    'stems': ['digit', 'of', 'servic']},
#   17: {'text': 'information', 'lemmas': ['information'], 'stems': ['inform']},
#   18: {'text': 'product information',
#    'lemmas': ['product', 'information'],
#    'stems': ['product', 'inform']},
#   19: {'text': 'service information',
#    'lemmas': ['service', 'information'],
#    'stems': ['servic', 'inform']},
#   20: {'text': 'ecosystem', 'lemmas': ['ecosystem'], 'stems': ['ecosystem']},
#   21: {'text': 'business ecosystem',
#    'lemmas': ['business', 'ecosystem'],
#    'stems': ['busi', 'ecosystem']},
#   22: {'text': 'digital ecosystem',
#    'lemmas': ['digital', 'ecosystem'],
#    'stems': ['digit', 'ecosystem']},
#   23: {'text': 'dynamic ecosystem',
#    'lemmas': ['dynamic', 'ecosystem'],
#    'stems': ['dynam', 'ecosystem']},
#   24: {'text': 'corporate scope',
#    'lemmas': ['corporate', 'scope'],
#    'stems': ['corpor', 'scope']},
#   25: {'text': 'portfolio', 'lemmas': ['portfolio'], 'stems': ['portfolio']},
#   26: {'text': 'control', 'lemmas': ['control'], 'stems': ['control']},
#   27: {'text': 'ownership', 'lemmas': ['ownership'], 'stems': ['ownership']},
#   28: {'text': 'diversification',
#    'lemmas': ['diversification'],
#    'stems': ['diversif']},
#   29: {'text': 'extend product reach',
#    'lemmas': ['extend', 'product', 'reach'],
#    'stems': ['extend', 'product', 'reach']},
#   30: {'text': 'extend market reach',
#    'lemmas': ['extend', 'market', 'reach'],
#    'stems': ['extend', 'market', 'reach']},
#   31: {'text': 'boundaries', 'lemmas': ['boundary'], 'stems': ['boundari']},
#   32: {'text': 'relationship',
#    'lemmas': ['relationship'],
#    'stems': ['relationship']},
#   33: {'text': 'environment', 'lemmas': ['environment'], 'stems': ['environ']},
#   34: {'text': 'competitive',
#    'lemmas': ['competitive'],
#    'stems': ['competit']},
#   35: {'text': 'cross-functional',
#    'lemmas': ['cross', '-', 'functional'],
#    'stems': ['cross', '-', 'function']},
#   36: {'text': 'transfunctional',
#    'lemmas': ['transfunctional'],
#    'stems': ['transfunct']},
#   37: {'text': 'multifunctional',
#    'lemmas': ['multifunctional'],
#    'stems': ['multifunct']},
#   38: {'text': 'multi-disciplinary',
#    'lemmas': ['multi', '-', 'disciplinary'],
#    'stems': ['multi', '-', 'disciplinari']},
#   39: {'text': 'cross-disciplinary',
#    'lemmas': ['cross', '-', 'disciplinary'],
#    'stems': ['cross', '-', 'disciplinari']},
#   40: {'text': 'IT-enabled business processes',
#    'lemmas': ['it', '-', 'enable', 'business', 'process'],
#    'stems': ['it', '-', 'enabl', 'busi', 'process']},
#   41: {'text': 'information exchanges',
#    'lemmas': ['information', 'exchange'],
#    'stems': ['inform', 'exchang']},
#   42: {'text': 'digital platforms',
#    'lemmas': ['digital', 'platform'],
#    'stems': ['digit', 'platform']},
#   43: {'text': 'inside', 'lemmas': ['inside'], 'stems': ['insid']},
#   44: {'text': 'outside', 'lemmas': ['outside'], 'stems': ['outsid']},
#   45: {'text': 'interconnected',
#    'lemmas': ['interconnect'],
#    'stems': ['interconnect']},
#   46: {'text': 'broader', 'lemmas': ['broad'], 'stems': ['broader']},
#   47: {'text': 'embedded', 'lemmas': ['embed'], 'stems': ['embed']},
#   48: {'text': 'digital design of product',
#    'lemmas': ['digital', 'design', 'of', 'product'],
#    'stems': ['digit', 'design', 'of', 'product']},
#   49: {'text': 'digital design of service',
#    'lemmas': ['digital', 'design', 'of', 'service'],
#    'stems': ['digit', 'design', 'of', 'servic']},
#   50: {'text': 'interoperability',
#    'lemmas': ['interoperability'],
#    'stems': ['interoper']},
#   51: {'text': 'key digital resource',
#    'lemmas': ['key', 'digital', 'resource'],
#    'stems': ['key', 'digit', 'resourc']},
#   52: {'text': 'linkage', 'lemmas': ['linkage'], 'stems': ['linkag']},
#   53: {'text': 'novel digital resource',
#    'lemmas': ['novel', 'digital', 'resource'],
#    'stems': ['novel', 'digit', 'resourc']},
#   54: {'text': 'expand the scope',
#    'lemmas': ['expand', 'the', 'scope'],
#    'stems': ['expand', 'the', 'scope']},
#   55: {'text': 'digitized product architecture',
#    'lemmas': ['digitize', 'product', 'architecture'],
#    'stems': ['digit', 'product', 'architectur']},
#   56: {'text': 'digital product architecture',
#    'lemmas': ['digital', 'product', 'architecture'],
#    'stems': ['digit', 'product', 'architectur']},
#   57: {'text': 'bits and bytes',
#    'lemmas': ['bit', 'and', 'byte'],
#    'stems': ['bit', 'and', 'byte']},
#   58: {'text': 'digital infrastructure',
#    'lemmas': ['digital', 'infrastructure'],
#    'stems': ['digit', 'infrastructur']},
#   59: {'text': 'protocols', 'lemmas': ['protocol'], 'stems': ['protocol']},
#   60: {'text': 'data', 'lemmas': ['datum'], 'stems': ['data']},
#   61: {'text': 'information', 'lemmas': ['information'], 'stems': ['inform']},
#   62: {'text': 'social media',
#    'lemmas': ['social', 'medium'],
#    'stems': ['social', 'media']},
#   63: {'text': 'big data',
#    'lemmas': ['big', 'datum'],
#    'stems': ['big', 'data']},
#   64: {'text': 'connectivity',
#    'lemmas': ['connectivity'],
#    'stems': ['connect']},
#   65: {'text': 'informationbased',
#    'lemmas': ['informationbase'],
#    'stems': ['informationbas']},
#   66: {'text': 'metrics', 'lemmas': ['metric'], 'stems': ['metric']},
#   67: {'text': 'hardware', 'lemmas': ['hardware'], 'stems': ['hardwar']},
#   68: {'text': 'software', 'lemmas': ['software'], 'stems': ['softwar']},
#   69: {'text': 'connected', 'lemmas': ['connect'], 'stems': ['connect']},
#   70: {'text': 'digital connections',
#    'lemmas': ['digital', 'connection'],
#    'stems': ['digit', 'connect']},
#   71: {'text': 'digital conditions',
#    'lemmas': ['digital', 'condition'],
#    'stems': ['digit', 'condit']},
#   72: {'text': 'supply Chain',
#    'lemmas': ['supply', 'chain'],
#    'stems': ['suppli', 'chain']},
#   73: {'text': 'supply network',
#    'lemmas': ['supply', 'network'],
#    'stems': ['suppli', 'network']},
#   74: {'text': 'digitally intensive',
#    'lemmas': ['digitally', 'intensive'],
#    'stems': ['digit', 'intens']},
#   75: {'text': 'alliances', 'lemmas': ['alliance'], 'stems': ['allianc']},
#   76: {'text': 'partnerships',
#    'lemmas': ['partnership'],
#    'stems': ['partnership']},
#   77: {'text': 'competitors',
#    'lemmas': ['competitor'],
#    'stems': ['competitor']},
#   78: {'text': 'spaces', 'lemmas': ['space'], 'stems': ['space']},
#   79: {'text': 'niches', 'lemmas': ['niche'], 'stems': ['nich']},
#   80: {'text': 'partners', 'lemmas': ['partner'], 'stems': ['partner']},
#   81: {'text': 'orchestration',
#    'lemmas': ['orchestration'],
#    'stems': ['orchestr']},
#   82: {'text': 'multifaceted',
#    'lemmas': ['multifacete'],
#    'stems': ['multifacet']},
#   83: {'text': 'data rich',
#    'lemmas': ['datum', 'rich'],
#    'stems': ['data', 'rich']},
#   84: {'text': 'dynamic', 'lemmas': ['dynamic'], 'stems': ['dynam']},
#   85: {'text': 'digital dependency',
#    'lemmas': ['digital', 'dependency'],
#    'stems': ['digit', 'depend']},
#   86: {'text': 'coverage', 'lemmas': ['coverage'], 'stems': ['coverag']},
#   87: {'text': 'geographic', 'lemmas': ['geographic'], 'stems': ['geograph']}},
#  'Scale of Digital Business Strategy': {0: {'text': 'Scale',
#    'lemmas': ['scale'],
#    'stems': ['scale']},
#   1: {'text': 'rapidly', 'lemmas': ['rapidly'], 'stems': ['rapidli']},
#   2: {'text': 'effectively', 'lemmas': ['effectively'], 'stems': ['effect']},
#   3: {'text': 'IT infrastructure',
#    'lemmas': ['it', 'infrastructure'],
#    'stems': ['it', 'infrastructur']},
#   4: {'text': 'infrastructure',
#    'lemmas': ['infrastructure'],
#    'stems': ['infrastructur']},
#   5: {'text': 'Enable', 'lemmas': ['enable'], 'stems': ['enabl']},
#   6: {'text': 'bolster', 'lemmas': ['bolster'], 'stems': ['bolster']},
#   7: {'text': 'dynamic capability',
#    'lemmas': ['dynamic', 'capability'],
#    'stems': ['dynam', 'capabl']},
#   8: {'text': 'network effects',
#    'lemmas': ['network', 'effect'],
#    'stems': ['network', 'effect']},
#   9: {'text': 'multisided platforms',
#    'lemmas': ['multisided', 'platform'],
#    'stems': ['multisid', 'platform']},
#   10: {'text': 'data abundance',
#    'lemmas': ['datum', 'abundance'],
#    'stems': ['data', 'abund']},
#   11: {'text': 'information abundance',
#    'lemmas': ['information', 'abundance'],
#    'stems': ['inform', 'abund']},
#   12: {'text': 'knowledge abundance',
#    'lemmas': ['knowledge', 'abundance'],
#    'stems': ['knowledg', 'abund']},
#   13: {'text': 'volume', 'lemmas': ['volume'], 'stems': ['volum']},
#   14: {'text': 'cloud', 'lemmas': ['cloud'], 'stems': ['cloud']},
#   15: {'text': 'driver', 'lemmas': ['driver'], 'stems': ['driver']},
#   16: {'text': 'profitability',
#    'lemmas': ['profitability'],
#    'stems': ['profit']},
#   17: {'text': 'cost', 'lemmas': ['cost'], 'stems': ['cost']},
#   18: {'text': 'unit cost',
#    'lemmas': ['unit', 'cost'],
#    'stems': ['unit', 'cost']},
#   19: {'text': 'physical', 'lemmas': ['physical'], 'stems': ['physic']},
#   20: {'text': 'scale up',
#    'lemmas': ['scale', 'up'],
#    'stems': ['scale', 'up']},
#   21: {'text': 'scale down',
#    'lemmas': ['scale', 'down'],
#    'stems': ['scale', 'down']},
#   22: {'text': 'availability', 'lemmas': ['availability'], 'stems': ['avail']},
#   23: {'text': 'reliance', 'lemmas': ['reliance'], 'stems': ['relianc']},
#   24: {'text': 'on-demand',
#    'lemmas': ['on', '-', 'demand'],
#    'stems': ['on', '-', 'demand']},
#   25: {'text': 'shared', 'lemmas': ['share'], 'stems': ['share']},
#   26: {'text': 'configurable',
#    'lemmas': ['configurable'],
#    'stems': ['configur']},
#   27: {'text': 'computing', 'lemmas': ['compute'], 'stems': ['comput']},
#   28: {'text': 'self-service',
#    'lemmas': ['self', '-', 'service'],
#    'stems': ['self', '-', 'servic']},
#   29: {'text': 'virtualized', 'lemmas': ['virtualize'], 'stems': ['virtual']},
#   30: {'text': 'elastic', 'lemmas': ['elastic'], 'stems': ['elast']},
#   31: {'text': 'utilization', 'lemmas': ['utilization'], 'stems': ['util']},
#   32: {'text': 'access', 'lemmas': ['access'], 'stems': ['access']},
#   33: {'text': 'measure', 'lemmas': ['measure'], 'stems': ['measur']},
#   34: {'text': 'quality of service',
#    'lemmas': ['quality', 'of', 'service'],
#    'stems': ['qualiti', 'of', 'servic']},
#   35: {'text': 'operations', 'lemmas': ['operation'], 'stems': ['oper']},
#   36: {'text': 'functional', 'lemmas': ['functional'], 'stems': ['function']},
#   37: {'text': 'ability', 'lemmas': ['ability'], 'stems': ['abil']},
#   38: {'text': 'adapt', 'lemmas': ['adapt'], 'stems': ['adapt']},
#   39: {'text': 'requirement', 'lemmas': ['requirement'], 'stems': ['requir']},
#   40: {'text': 'marketplace',
#    'lemmas': ['marketplace'],
#    'stems': ['marketplac']},
#   41: {'text': 'pay-as-you-go',
#    'lemmas': ['pay', '-', 'as', '-', 'you', '-', 'go'],
#    'stems': ['pay', '-', 'as', '-', 'you', '-', 'go']},
#   42: {'text': 'pressure', 'lemmas': ['pressure'], 'stems': ['pressur']},
#   43: {'text': 'potential', 'lemmas': ['potential'], 'stems': ['potenti']},
#   44: {'text': 'interconnected partnerships',
#    'lemmas': ['interconnected', 'partnership'],
#    'stems': ['interconnect', 'partnership']},
#   45: {'text': 'interconnections',
#    'lemmas': ['interconnection'],
#    'stems': ['interconnect']},
#   46: {'text': 'web page',
#    'lemmas': ['web', 'page'],
#    'stems': ['web', 'page']},
#   47: {'text': 'broadband', 'lemmas': ['broadband'], 'stems': ['broadband']},
#   48: {'text': 'smart', 'lemmas': ['smart'], 'stems': ['smart']},
#   49: {'text': 'device', 'lemmas': ['device'], 'stems': ['devic']},
#   50: {'text': 'amplified', 'lemmas': ['amplify'], 'stems': ['amplifi']},
#   51: {'text': 'networked abundance',
#    'lemmas': ['networked', 'abundance'],
#    'stems': ['network', 'abund']},
#   52: {'text': 'internet of things',
#    'lemmas': ['internet', 'of', 'thing'],
#    'stems': ['internet', 'of', 'thing']},
#   53: {'text': 'IoT', 'lemmas': ['iot'], 'stems': ['iot']},
#   54: {'text': 'quantities', 'lemmas': ['quantity'], 'stems': ['quantiti']},
#   55: {'text': 'heterogeneous',
#    'lemmas': ['heterogeneous'],
#    'stems': ['heterogen']},
#   56: {'text': 'continuous', 'lemmas': ['continuous'], 'stems': ['continu']},
#   57: {'text': 'basis', 'lemmas': ['basis'], 'stems': ['basi']},
#   58: {'text': 'chatter', 'lemmas': ['chatter'], 'stems': ['chatter']},
#   59: {'text': 'social networks',
#    'lemmas': ['social', 'network'],
#    'stems': ['social', 'network']},
#   60: {'text': 'crowdsourcing',
#    'lemmas': ['crowdsource'],
#    'stems': ['crowdsourc']},
#   61: {'text': 'edge', 'lemmas': ['edge'], 'stems': ['edg']},
#   62: {'text': 'machine-to-machine',
#    'lemmas': ['machine', '-', 'to', '-', 'machine'],
#    'stems': ['machin', '-', 'to', '-', 'machin']},
#   63: {'text': 'sensor', 'lemmas': ['sensor'], 'stems': ['sensor']},
#   64: {'text': 'options', 'lemmas': ['option'], 'stems': ['option']},
#   65: {'text': 'crossselling',
#    'lemmas': ['crossselle'],
#    'stems': ['crosssel']},
#   66: {'text': 'cross-selling',
#    'lemmas': ['cross', '-', 'sell'],
#    'stems': ['cross', '-', 'sell']},
#   67: {'text': 'together', 'lemmas': ['together'], 'stems': ['togeth']},
#   68: {'text': 'digital setting',
#    'lemmas': ['digital', 'setting'],
#    'stems': ['digit', 'set']},
#   69: {'text': 'setting', 'lemmas': ['set'], 'stems': ['set']},
#   70: {'text': 'modularize', 'lemmas': ['modularize'], 'stems': ['modular']},
#   71: {'text': 'modul', 'lemmas': ['modul'], 'stems': ['modul']},
#   72: {'text': 'plug-and-play',
#    'lemmas': ['plug', '-', 'and', '-', 'play'],
#    'stems': ['plug', '-', 'and', '-', 'play']},
#   73: {'text': 'digital assets',
#    'lemmas': ['digital', 'asset'],
#    'stems': ['digit', 'asset']},
#   74: {'text': 'application programming interfaces',
#    'lemmas': ['application', 'programming', 'interface'],
#    'stems': ['applic', 'program', 'interfac']},
#   75: {'text': 'API', 'lemmas': ['API'], 'stems': ['api']},
#   76: {'text': 'web services',
#    'lemmas': ['web', 'service'],
#    'stems': ['web', 'servic']}},
#  'Speed of Digital Business Strategy': {0: {'text': 'speed',
#    'lemmas': ['speed'],
#    'stems': ['speed']},
#   1: {'text': 'accelerate', 'lemmas': ['accelerate'], 'stems': ['acceler']},
#   2: {'text': 'accelerating', 'lemmas': ['accelerate'], 'stems': ['acceler']},
#   3: {'text': 'product launch',
#    'lemmas': ['product', 'launch'],
#    'stems': ['product', 'launch']},
#   4: {'text': 'just-in-time',
#    'lemmas': ['just', '-', 'in', '-', 'time'],
#    'stems': ['just', '-', 'in', '-', 'time']},
#   5: {'text': 'launch', 'lemmas': ['launch'], 'stems': ['launch']},
#   6: {'text': 'learning', 'lemmas': ['learn'], 'stems': ['learn']},
#   7: {'text': 'improve', 'lemmas': ['improve'], 'stems': ['improv']},
#   8: {'text': 'improving', 'lemmas': ['improve'], 'stems': ['improv']},
#   9: {'text': 'decision-making',
#    'lemmas': ['decision', '-', 'making'],
#    'stems': ['decis', '-', 'make']},
#   10: {'text': 'decision', 'lemmas': ['decision'], 'stems': ['decis']},
#   11: {'text': 'bolster', 'lemmas': ['bolster'], 'stems': ['bolster']},
#   12: {'text': 'quickly', 'lemmas': ['quickly'], 'stems': ['quickli']},
#   13: {'text': 'quick', 'lemmas': ['quick'], 'stems': ['quick']},
#   14: {'text': 'formation', 'lemmas': ['formation'], 'stems': ['format']},
#   15: {'text': 'provide', 'lemmas': ['provide'], 'stems': ['provid']},
#   16: {'text': 'complementary',
#    'lemmas': ['complementary'],
#    'stems': ['complementari']},
#   17: {'text': 'sense', 'lemmas': ['sense'], 'stems': ['sens']},
#   18: {'text': 'respond', 'lemmas': ['respond'], 'stems': ['respond']},
#   19: {'text': 'cycle', 'lemmas': ['cycle'], 'stems': ['cycl']},
#   20: {'text': 'real-time',
#    'lemmas': ['real', '-', 'time'],
#    'stems': ['real', '-', 'time']},
#   21: {'text': 'time', 'lemmas': ['time'], 'stems': ['time']},
#   22: {'text': 'timely', 'lemmas': ['timely'], 'stems': ['time']},
#   23: {'text': 'central', 'lemmas': ['central'], 'stems': ['central']},
#   24: {'text': 'pervasive', 'lemmas': ['pervasive'], 'stems': ['pervas']},
#   25: {'text': 'series', 'lemmas': ['series'], 'stems': ['seri']},
#   26: {'text': 'improvement', 'lemmas': ['improvement'], 'stems': ['improv']},
#   27: {'text': 'hybrid', 'lemmas': ['hybrid'], 'stems': ['hybrid']},
#   28: {'text': 'product introduction',
#    'lemmas': ['product', 'introduction'],
#    'stems': ['product', 'introduct']},
#   29: {'text': 'introduction',
#    'lemmas': ['introduction'],
#    'stems': ['introduct']},
#   30: {'text': 'initiative', 'lemmas': ['initiative'], 'stems': ['initi']},
#   31: {'text': 'add', 'lemmas': ['add'], 'stems': ['add']},
#   32: {'text': 'dimension', 'lemmas': ['dimension'], 'stems': ['dimens']},
#   33: {'text': 'clock', 'lemmas': ['clock'], 'stems': ['clock']},
#   34: {'text': 'recalibrate',
#    'lemmas': ['recalibrate'],
#    'stems': ['recalibr']},
#   35: {'text': 'calibrate', 'lemmas': ['calibrate'], 'stems': ['calibr']},
#   36: {'text': 'predictable improvements',
#    'lemmas': ['predictable', 'improvement'],
#    'stems': ['predict', 'improv']},
#   37: {'text': 'functionality',
#    'lemmas': ['functionality'],
#    'stems': ['function']},
#   38: {'text': 'multiyear', 'lemmas': ['multiyear'], 'stems': ['multiyear']},
#   39: {'text': 'sequence', 'lemmas': ['sequence'], 'stems': ['sequenc']},
#   40: {'text': 'remain', 'lemmas': ['remain'], 'stems': ['remain']},
#   41: {'text': 'decade', 'lemmas': ['decade'], 'stems': ['decad']},
#   42: {'text': 'recent', 'lemmas': ['recent'], 'stems': ['recent']},
#   43: {'text': 'combine', 'lemmas': ['combine'], 'stems': ['combin']},
#   44: {'text': 'bandwidth', 'lemmas': ['bandwidth'], 'stems': ['bandwidth']},
#   45: {'text': 'mobile', 'lemmas': ['mobile'], 'stems': ['mobil']},
#   46: {'text': 'plan', 'lemmas': ['plan'], 'stems': ['plan']},
#   47: {'text': 'planned', 'lemmas': ['plan'], 'stems': ['plan']},
#   48: {'text': 'obsolescence',
#    'lemmas': ['obsolescence'],
#    'stems': ['obsolesc']},
#   49: {'text': 'recognize', 'lemmas': ['recognize'], 'stems': ['recogn']},
#   50: {'text': 'respond', 'lemmas': ['respond'], 'stems': ['respond']},
#   51: {'text': 'fast-paced',
#    'lemmas': ['fast', '-', 'pace'],
#    'stems': ['fast', '-', 'pace']},
#   52: {'text': 'pace', 'lemmas': ['pace'], 'stems': ['pace']},
#   53: {'text': 'innovation', 'lemmas': ['innovation'], 'stems': ['innov']},
#   54: {'text': 'implementation',
#    'lemmas': ['implementation'],
#    'stems': ['implement']},
#   55: {'text': 'fundamental',
#    'lemmas': ['fundamental'],
#    'stems': ['fundament']},
#   56: {'text': 'competitive',
#    'lemmas': ['competitive'],
#    'stems': ['competit']},
#   57: {'text': 'success', 'lemmas': ['success'], 'stems': ['success']},
#   58: {'text': 'survival', 'lemmas': ['survival'], 'stems': ['surviv']},
#   59: {'text': 'coordination',
#    'lemmas': ['coordination'],
#    'stems': ['coordin']},
#   60: {'text': 'control', 'lemmas': ['control'], 'stems': ['control']},
#   61: {'text': 'standalone', 'lemmas': ['standalone'], 'stems': ['standalon']},
#   62: {'text': 'autonomous', 'lemmas': ['autonomous'], 'stems': ['autonom']},
#   63: {'text': 'availability', 'lemmas': ['availability'], 'stems': ['avail']},
#   64: {'text': 'slow', 'lemmas': ['slow'], 'stems': ['slow']},
#   65: {'text': 'slowness', 'lemmas': ['slowness'], 'stems': ['slow']},
#   66: {'text': 'information flow',
#    'lemmas': ['information', 'flow'],
#    'stems': ['inform', 'flow']},
#   67: {'text': 'flow', 'lemmas': ['flow'], 'stems': ['flow']},
#   68: {'text': 'hierarchy', 'lemmas': ['hierarchy'], 'stems': ['hierarchi']},
#   69: {'text': 'multiple', 'lemmas': ['multiple'], 'stems': ['multipl']},
#   70: {'text': 'layer', 'lemmas': ['layer'], 'stems': ['layer']},
#   71: {'text': 'stream', 'lemmas': ['stream'], 'stems': ['stream']},
#   72: {'text': 'focal', 'lemmas': ['focal'], 'stems': ['focal']},
#   73: {'text': 'partners', 'lemmas': ['partner'], 'stems': ['partner']},
#   74: {'text': 'allies', 'lemmas': ['ally'], 'stems': ['alli']},
#   75: {'text': 'responding', 'lemmas': ['respond'], 'stems': ['respond']},
#   76: {'text': 'customer service',
#    'lemmas': ['customer', 'service'],
#    'stems': ['custom', 'servic']},
#   77: {'text': 'request', 'lemmas': ['request'], 'stems': ['request']},
#   78: {'text': 'Twitter', 'lemmas': ['twitter'], 'stems': ['twitter']},
#   79: {'text': 'Facebook', 'lemmas': ['Facebook'], 'stems': ['facebook']},
#   80: {'text': 'social media',
#    'lemmas': ['social', 'medium'],
#    'stems': ['social', 'media']},
#   81: {'text': 'move', 'lemmas': ['move'], 'stems': ['move']},
#   82: {'text': 'tune', 'lemmas': ['tune'], 'stems': ['tune']},
#   83: {'text': 'reality', 'lemmas': ['reality'], 'stems': ['realiti']},
#   84: {'text': 'variety', 'lemmas': ['variety'], 'stems': ['varieti']},
#   85: {'text': 'experiment', 'lemmas': ['experiment'], 'stems': ['experi']},
#   86: {'text': 'integrative', 'lemmas': ['integrative'], 'stems': ['integr']},
#   87: {'text': 'command', 'lemmas': ['command'], 'stems': ['command']},
#   88: {'text': 'organize', 'lemmas': ['organize'], 'stems': ['organ']},
#   89: {'text': 'analyze', 'lemmas': ['analyze'], 'stems': ['analyz']},
#   90: {'text': 'accumulate', 'lemmas': ['accumulate'], 'stems': ['accumul']},
#   91: {'text': 'transaction',
#    'lemmas': ['transaction'],
#    'stems': ['transact']},
#   92: {'text': 'elapse', 'lemmas': ['elapse'], 'stems': ['elaps']},
#   93: {'text': 'correspond',
#    'lemmas': ['correspond'],
#    'stems': ['correspond']},
#   94: {'text': 'wave', 'lemmas': ['wave'], 'stems': ['wave']},
#   95: {'text': 'redesign', 'lemmas': ['redesign'], 'stems': ['redesign']},
#   96: {'text': 'effective', 'lemmas': ['effective'], 'stems': ['effect']},
#   97: {'text': 'end-to-end',
#    'lemmas': ['end', '-', 'to', '-', 'end'],
#    'stems': ['end', '-', 'to', '-', 'end']},
#   98: {'text': 'visibility', 'lemmas': ['visibility'], 'stems': ['visibl']},
#   99: {'text': 'efficient', 'lemmas': ['efficient'], 'stems': ['effici']},
#   100: {'text': 'coupled', 'lemmas': ['couple'], 'stems': ['coupl']},
#   101: {'text': 'outsourcing', 'lemmas': ['outsource'], 'stems': ['outsourc']},
#   102: {'text': 'non-core',
#    'lemmas': ['non', '-', 'core'],
#    'stems': ['non', '-', 'core']},
#   103: {'text': 'interfirm', 'lemmas': ['interfirm'], 'stems': ['interfirm']},
#   104: {'text': 'announcing', 'lemmas': ['announce'], 'stems': ['announc']},
#   105: {'text': 'announce', 'lemmas': ['announce'], 'stems': ['announc']},
#   106: {'text': 'first-mover',
#    'lemmas': ['first', '-', 'mover'],
#    'stems': ['first', '-', 'mover']},
#   107: {'text': 'global', 'lemmas': ['global'], 'stems': ['global']},
#   108: {'text': 'non-value',
#    'lemmas': ['non', '-', 'value'],
#    'stems': ['non', '-', 'valu']},
#   109: {'text': 'collaborative',
#    'lemmas': ['collaborative'],
#    'stems': ['collabor']},
#   110: {'text': 'conceptual', 'lemmas': ['conceptual'], 'stems': ['conceptu']},
#   111: {'text': 'tomorrow', 'lemmas': ['tomorrow'], 'stems': ['tomorrow']},
#   112: {'text': 'realignment',
#    'lemmas': ['realignment'],
#    'stems': ['realign']},
#   113: {'text': 'adaptation', 'lemmas': ['adaptation'], 'stems': ['adapt']},
#   114: {'text': 'apps', 'lemmas': ['app'], 'stems': ['app']},
#   115: {'text': 'insights', 'lemmas': ['insight'], 'stems': ['insight']}},
#  'Sources of Value Creation and Capture': {0: {'text': 'source',
#    'lemmas': ['source'],
#    'stems': ['sourc']},
#   1: {'text': 'value', 'lemmas': ['value'], 'stems': ['valu']},
#   2: {'text': 'capture', 'lemmas': ['capture'], 'stems': ['captur']},
#   3: {'text': 'leveraging', 'lemmas': ['leverage'], 'stems': ['leverag']},
#   4: {'text': 'leverage', 'lemmas': ['leverage'], 'stems': ['leverag']},
#   5: {'text': 'business models',
#    'lemmas': ['business', 'model'],
#    'stems': ['busi', 'model']},
#   6: {'text': 'capturing', 'lemmas': ['capture'], 'stems': ['captur']},
#   7: {'text': 'appropriating',
#    'lemmas': ['appropriate'],
#    'stems': ['appropri']},
#   8: {'text': 'appropriation',
#    'lemmas': ['appropriation'],
#    'stems': ['appropri']},
#   9: {'text': 'digital architecture',
#    'lemmas': ['digital', 'architecture'],
#    'stems': ['digit', 'architectur']},
#   10: {'text': 'profitability',
#    'lemmas': ['profitability'],
#    'stems': ['profit']},
#   11: {'text': 'value creation',
#    'lemmas': ['value', 'creation'],
#    'stems': ['valu', 'creation']},
#   12: {'text': 'value capture',
#    'lemmas': ['value', 'capture'],
#    'stems': ['valu', 'captur']},
#   13: {'text': 'robust', 'lemmas': ['robust'], 'stems': ['robust']},
#   14: {'text': 'intangible', 'lemmas': ['intangible'], 'stems': ['intang']},
#   15: {'text': 'information-based',
#    'lemmas': ['information', '-', 'base'],
#    'stems': ['inform', '-', 'base']},
#   16: {'text': 'opportunities',
#    'lemmas': ['opportunity'],
#    'stems': ['opportun']},
#   17: {'text': 'fundamental',
#    'lemmas': ['fundamental'],
#    'stems': ['fundament']},
#   18: {'text': 'rethink', 'lemmas': ['rethink'], 'stems': ['rethink']},
#   19: {'text': 'unique', 'lemmas': ['unique'], 'stems': ['uniqu']},
#   20: {'text': 'curating', 'lemmas': ['curate'], 'stems': ['curat']},
#   21: {'text': 'content', 'lemmas': ['content'], 'stems': ['content']},
#   22: {'text': 'assess', 'lemmas': ['assess'], 'stems': ['assess']},
#   23: {'text': 'balance', 'lemmas': ['balance'], 'stems': ['balanc']},
#   24: {'text': 'subscription',
#    'lemmas': ['subscription'],
#    'stems': ['subscript']},
#   25: {'text': 'advertising',
#    'lemmas': ['advertising'],
#    'stems': ['advertis']},
#   26: {'text': 'financial', 'lemmas': ['financial'], 'stems': ['financi']},
#   27: {'text': 'accurate', 'lemmas': ['accurate'], 'stems': ['accur']},
#   28: {'text': 'fine-tune',
#    'lemmas': ['fine', '-', 'tune'],
#    'stems': ['fine', '-', 'tune']},
#   29: {'text': 'personalize', 'lemmas': ['personalize'], 'stems': ['person']},
#   30: {'text': 'offerings', 'lemmas': ['offering'], 'stems': ['offer']},
#   31: {'text': 'preferences', 'lemmas': ['preference'], 'stems': ['prefer']},
#   32: {'text': 'democratization',
#    'lemmas': ['democratization'],
#    'stems': ['democrat']},
#   33: {'text': 'content', 'lemmas': ['content'], 'stems': ['content']},
#   34: {'text': 'sharing', 'lemmas': ['share'], 'stems': ['share']},
#   35: {'text': 'remixing', 'lemmas': ['remixe'], 'stems': ['remix']},
#   36: {'text': 'redistribution',
#    'lemmas': ['redistribution'],
#    'stems': ['redistribut']},
#   37: {'text': 'resyndication',
#    'lemmas': ['resyndication'],
#    'stems': ['resynd']},
#   38: {'text': 'dramatic', 'lemmas': ['dramatic'], 'stems': ['dramat']},
#   39: {'text': 'power', 'lemmas': ['power'], 'stems': ['power']},
#   40: {'text': 'shifts', 'lemmas': ['shift'], 'stems': ['shift']},
#   41: {'text': 'channel', 'lemmas': ['channel'], 'stems': ['channel']},
#   42: {'text': 'disintermediation',
#    'lemmas': ['disintermediation'],
#    'stems': ['disintermedi']},
#   43: {'text': 'disrupt', 'lemmas': ['disrupt'], 'stems': ['disrupt']},
#   44: {'text': 'sharp', 'lemmas': ['sharp'], 'stems': ['sharp']},
#   45: {'text': 'importance', 'lemmas': ['importance'], 'stems': ['import']},
#   46: {'text': 'revenue', 'lemmas': ['revenue'], 'stems': ['revenu']},
#   47: {'text': 'free', 'lemmas': ['free'], 'stems': ['free']},
#   48: {'text': 'monetizing', 'lemmas': ['monetize'], 'stems': ['monet']},
#   49: {'text': 'influence', 'lemmas': ['influence'], 'stems': ['influenc']},
#   50: {'text': 'nuanced', 'lemmas': ['nuance'], 'stems': ['nuanc']},
#   51: {'text': 'conceptualize',
#    'lemmas': ['conceptualize'],
#    'stems': ['conceptu']},
#   52: {'text': 'interactions',
#    'lemmas': ['interaction'],
#    'stems': ['interact']},
#   53: {'text': 'logical', 'lemmas': ['logical'], 'stems': ['logic']},
#   54: {'text': 'recognition',
#    'lemmas': ['recognition'],
#    'stems': ['recognit']},
#   55: {'text': 'quality', 'lemmas': ['quality'], 'stems': ['qualiti']},
#   56: {'text': 'involve', 'lemmas': ['involve'], 'stems': ['involv']},
#   57: {'text': 'complex', 'lemmas': ['complex'], 'stems': ['complex']},
#   58: {'text': 'cocreate', 'lemmas': ['cocreate'], 'stems': ['cocreat']},
#   59: {'text': 'complicating', 'lemmas': ['complicate'], 'stems': ['complic']},
#   60: {'text': 'factor', 'lemmas': ['factor'], 'stems': ['factor']},
#   61: {'text': 'independent',
#    'lemmas': ['independent'],
#    'stems': ['independ']},
#   62: {'text': 'intersect', 'lemmas': ['intersect'], 'stems': ['intersect']},
#   63: {'text': 'interoperate',
#    'lemmas': ['interoperate'],
#    'stems': ['interoper']},
#   64: {'text': 'players', 'lemmas': ['player'], 'stems': ['player']},
#   65: {'text': 'rich', 'lemmas': ['rich'], 'stems': ['rich']},
#   66: {'text': 'richer', 'lemmas': ['rich'], 'stems': ['richer']},
#   67: {'text': 'delineate', 'lemmas': ['delineate'], 'stems': ['delin']},
#   68: {'text': 'evolve.', 'lemmas': ['evolve', '.'], 'stems': ['evolv', '.']},
#   69: {'text': 'market share',
#    'lemmas': ['market', 'share'],
#    'stems': ['market', 'share']},
#   70: {'text': 'lead', 'lemmas': ['lead'], 'stems': ['lead']},
#   71: {'text': 'earn', 'lemmas': ['earn'], 'stems': ['earn']},
#   72: {'text': 'receive', 'lemmas': ['receive'], 'stems': ['receiv']},
#   73: {'text': 'follow-on',
#    'lemmas': ['follow', '-', 'on'],
#    'stems': ['follow', '-', 'on']},
#   74: {'text': 'extract', 'lemmas': ['extract'], 'stems': ['extract']},
#   75: {'text': 'high', 'lemmas': ['high'], 'stems': ['high']},
#   76: {'text': 'premium', 'lemmas': ['premium'], 'stems': ['premium']},
#   77: {'text': 'indication', 'lemmas': ['indication'], 'stems': ['indic']},
#   78: {'text': 'redefine', 'lemmas': ['redefine'], 'stems': ['redefin']},
#   79: {'text': 'disproportionate',
#    'lemmas': ['disproportionate'],
#    'stems': ['disproportion']},
#   80: {'text': 'position', 'lemmas': ['position'], 'stems': ['posit']},
#   81: {'text': 'metrics', 'lemmas': ['metric'], 'stems': ['metric']},
#   82: {'text': 'track', 'lemmas': ['track'], 'stems': ['track']},
#   83: {'text': 'follow', 'lemmas': ['follow'], 'stems': ['follow']},
#   84: {'text': 'performance', 'lemmas': ['performance'], 'stems': ['perform']},
#   85: {'text': 'important', 'lemmas': ['important'], 'stems': ['import']},
#   86: {'text': 'question', 'lemmas': ['question'], 'stems': ['question']},
#   87: {'text': 'formulate', 'lemmas': ['formulate'], 'stems': ['formul']},
#   88: {'text': 'execute', 'lemmas': ['execute'], 'stems': ['execut']},
#   89: {'text': 'differential',
#    'lemmas': ['differential'],
#    'stems': ['differenti']},
#   90: {'text': 'difference', 'lemmas': ['difference'], 'stems': ['differ']}}}
